# %% [markdown]
# <h1>3.МОДЕЛИРОВАНИЕ ВРЕМЕННЫХ РЯДОВ</h1>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# До настоящего момента мы рассматривали только вопросы сбора и извлечения временных рядов, а также их обработки. Далее будем создавать временных ряды в результате моделирования.<br>
# Три основных вопроса.<br>
# Во-первых, сравнить принципы моделирования временных рядов с таковыми в других способах моделирования данных, отмечая особенности процесса, вызванные необходимостью учета течения времени.<br>
# Во-вторых, изучить несколько программных примеров моделирования.<br>
# В-третьих, обсудить важные тенденции моделирования временных рядов.<br>
# Рассмотрим примеры кода, отвечающего за генерацию временных рядов разных типов. Среди них выделяются следующие наиболее важные ситуации.<br>
# • Моделирование поведения членов благотворительной организации, заключающегося в изучении почтовых сообщений и внесении добровольных пожертвований в течение всего срока членства в организации. Пример напрямую связан с данными, которые были описаны ранее year_joined.csv, donations.csv, emails.csv.<br>
# • Моделирование событий в таксопарке, насчитывающем 1000 автомобилей, каждый из которых описывается с разным временем начала смены и количеством перевозимых пассажиров в течение рабочего дня.<br>
# • Пошаговое моделирование состояния твердого магнитного тела при заданной температуре и размерах, описываемого строгими физическими законами.<br>
#
# Каждый пример подчиняется одному из следующих способов моделирования временных рядов.<br>
# *Эвристическое моделирование*<br>
# Мы сами решаем, как должен работать мир, обеспечиваем его “разумность” и самостоятельно пишем код управления таким миром.<br>
# *Моделирование дискретных событий*<br>
# Создаем объекты системы, подчиняющиеся определенным правилам, а затем активизируем их, чтобы посмотреть, как такая система будет эволюционировать с течением времени.<br>
# *Моделирование физических систем*<br>
# Применяем физические законы, чтобы отслеживать поведение системы с течением времени.<br>

# %% [markdown]
# <h2>Особенности моделирования временных рядов</h2>

# %% [markdown]
# Моделирование данных выступает разновидностью анализа данных, которому редко обучают, но который находит широкое применение при работе с временными рядами. Это следует из одного из недостатков временных данных: никакие две точки данных в одном и том же временном ряду не могут быть точно сопоставимыми, поскольку они относятся к разному времени. Как только мы задумаемся о том, что могло бы произойти в данный момент времени, сразу же перейдем в область моделирования.<br>
#
# Моделирование может описываться как простым, так и сложным процессами. С одной стороны, смоделированные данные можно встретить в любом учебнике по статистике, например, при изучении случайного блуждания. Обычно они генерируются в виде накопительных сумм некого случайного процесса (получаемого, например, с помощью пакета rnorm языка R) или периодической функции (в частности, синусоиды). С другой стороны, многие ученые и инженеры делают карьеру, изучая и описывая технологии моделирования данных временных рядов.<br>
#
# Моделирование временных рядов остается активной областью исследований (необычайно требовательной к производительности вычислительного оборудования) во многих отраслях и дисциплинах.<br>
#
# • Метеорология.<br>
#
# • Финансы.<br>
#
# • Эпидемиология.<br>
#
# • Квантовая химия.<br>
#
# • Физика плазмы.<br>
#
# В некоторых из представленных случаев фундаментальные правила поведения системы хорошо изучены, но описать их бывает трудно из-за высокой сложности уравнений (например, в метеорологии, квантовой химии, физике плазмы). Кроме того, далеко не всегда в системе известны все исследуемые величины, а сделать точный прогноз не представляется возможным из-за стохастической нелинейной природы изучаемых процессов (например, в финансах и эпидемиологии).<br>

# %% [markdown]
# <h2>Моделирование и прогнозирование</h2>

# %% [markdown]
# Моделирование и прогнозирование — схожие задачи. В обоих случаях сначала нужно сформулировать гипотезу о параметрах и поведении базовой системы, а затем экстраполировать имеющиеся данные для получения новых точек.<br>
# Наряду с этим нужно четко понимать различия между принципами моделирования и прогнозирования.<br>
#
# • Иногда качественные наблюдения проще обрабатывать методами моделирования, а не прогнозирования.<br>
#
# • Моделирование выполняется в определенном масштабе, что позволяет увидеть множество альтернативных сценариев, в то время как прогнозы составляются предельно точно.<br>
#
# • Моделирование — не такое рискованное занятие, как прогнозирование. Моделирование не влияет на события реальной жизни и не вызывает потерь важных ресурсов — в первых сеансах моделирования вы можете проявлять максимум фантазии и изобретательности. Конечно, рано или поздно вам захочется обосновать модель точно так же, так это делается в прогнозировании.<br>

# %% [markdown]
# <h2>Моделирование с помощью программного кода</h2>

# %% [markdown]
# Рассмотрим три примера программ моделирования временных рядов. Изучая их, постарайтесь понять, насколько большими могут быть наборы данных, используемые в качестве источников «временных рядов», генерируемых в процессе моделирования. Не забывайте, что периодичность временной выборки может устанавливаться предельно точно и зависеть от действий человека (например, день и время совершения добровольных пожертвований) или же носить неустановленный характер и задаваться с помощью неопределенных утверждений (n-й шаг физического моделирования).<br>
#
# Рассмотрим три примера моделирования.<br>
#
# • Моделирование искусственного набора данных для проверки гипотезы о поведении членов организации, в частности о том, что их отношение к электронным письмам, полученным от благотворительной организации, коррелирует (или нет) с готовностью вносить благотворительные пожертвования.<br>
# Это яркий пример жесткого генерирования исходных табличных данных и определения взаимосвязей между данными, устанавливаемых в программном коде с помощью циклов for и подобных им структур.<br>
#
# • Моделирование синтезированного набора данных, используемого для изучения совокупного поведения водителей в таксопарке с учетом рабочего графика и количества перевозимых пассажиров в зависимости от времени суток. В этом наборе данных акцент делается на объектно-ориентированных атрибутах языка Python и генераторах, которые оказываются незаменимыми при тестировании и изучении поведения системы.<br>
#
# • Моделирование физического поведения магнитного материала, заключающегося в переориентировании отдельных магнитных элементов, которые вначале пребывают в беспорядке, но в конечном итоге объединяются в хорошо упорядоченную систему. В этом примере показано, что принципы моделирования временных рядов могут основываться на физических законах, предопределяющих временной масштаб и другие характеристики модели.<br>

# %% [markdown]
# <h2>Самостоятельная работа</h2>

# %% [markdown]
# При написании программы моделирования необходимо помнить о логических правилах, определяющих поведение системы. Ниже рассматривается пример программы, в которой выполняется жесткая проверка логической целостности данных (например, из системы исключаются события, которые противоречат ее логике).<br>
#
# В начале кода проверяется состояние членства в организации — устанавливается количество членов благотворительной организации и моментов времени вступления в нее. Каждый из членов организации участника получает определенный статус.<br>

# %%
import pandas as pd
import numpy as np
import random

# %%
## Статус членов организации
years = ['2014', '2015', '2016', '2017', '2018']
memberStatus = ['bronze', 'silver', 'gold', 'inactive']
memberYears = np.random.choice(years, 1000, p = [0.1, 0.1, 0.15, 0.30, 0.35])
memberStats = np.random.choice(memberStatus, 1000, p = [0.5, 0.3, 0.1, 0.1])
yearJoined = pd.DataFrame({'yearJoined': memberYears, 'memberStats': memberStats})

# %% [markdown]
# В этом коде сделано несколько предположений и реализовано несколько важных правил моделирования процесса. В них задаются вероятности вступления в организацию в каждом анализируемом году. Кроме того, здесь предполагается, что статус члена организации никак не связан с годом вступления в организацию. В реальном мире ситуация выглядит несколько иначе — более точным будет предположение о существовании слабой связи между этими переменными, особенно в случаях заинтересованности организации в сохранении своих членов.<br>
#
# Далее в коде создается таблица со сведениями об открытии электронных писем членами организации в течение каждой недели. В данном случае считается, что организации свойственно следующее поведение: рассылка всем членам по три электронных письма в неделю. Кроме того, в коде определяются возможные поведенческие реакции членов организации на получение почтовых сообщений.<br>
#
# • Никогда не открывает электронную почту<br>
#
# • Максимальный уровень взаимодействия (постоянно открывает электронную почту)<br>
#
# • Увеличение или уменьшение уровня взаимодействия<br>
#
# Мы можем усложнить поведенческие правила, корректируя отдельные параметры модели в зависимости от принятия старых или создания новых предположений о ненаблюдаемых процессах, влияющих на данные.<br>

# %%
NUM_EMAILS_SENT_WEEKLY = 3
## Определение функций для разных поведенческих шаблонов
def never_opens (period_rng):
    return[ ]

def constant_open_rate(period_rng):
    n, p = NUM_EMAILS_SENT_WEEKLY, np.random.uniform(0, 1)
    num_opened = np.random.binomial (n, p, len(period_rng))
    return num_opened

def increasing_open_rate(period_rng):
    return open_rate_with_factor_change(period_rng, np.random.uniform(1.01, 1.30))

def decreasing_open_rate (period_rng):
    return open_rate_with_factor_change(period_rng, np.random.uniform(0.5, 0.99))

def open_rate_with_factor_change (period_rng, fac):
    if len(period_rng) < 1:
        return[ ]
    times = np.random.randint(0, len(period_rng), int(0.1 * len(period_rng)))
    num_opened = np.zeros(len (period_rng))
    for prd in range(0, len(period_rng), 2):
        try:
            n, p = NUM_EMAILS_SENT_WEEKLY, np.random.uniform(0, 1)
            num_opened[prd:(prd + 2) ] = np.random.binomial(n, p, 2)
            p = max (min (1, p * fac), 0)
        except:
            num_opened[prd] = np.random.binomial(n, p, 1)[0]
        for t in range(len(times)):
            num_opened[times[t]] = 0
        return num_opened

# %% [markdown]
# Выше в коде определены функции моделирования четырех различных типов поведения. Пользователи, никогда не открывающие отправленные им электронные письма<br>
# **never_opens()**<br>
# Пользователи, открывающие примерно одинаковое количество писем каждую неделю<br>
# **constant_open_rate()**<br>
# Пользователи, открывающие меньшее количество электронных писем каждую неделю<br>**decreasing_open_rate()**<br>
# Пользователи, открывающие большее количество электронных писем каждую неделю
# <br>**increasing_open_rate()**<br>
# Поведение членов организации, которые с течением времени становятся более активными или, наоборот, более пассивными, описывается подобным образом с помощью функции **open_rate_with_factor_change()**, основанной на функциях **increasing_open_rate()** и **decreasing_open_rate()**

# %% [markdown]
# Далее нам нужно определиться с моделью внесения добровольных пожертвований. Она не должна быть слишком простой, иначе это приведет к неправильному пониманию описываемых процессов. Другими словами, в модель внесения пожертвований нужно включить текущие предположения о поведении членов организации, а затем проверить, соответствуют ли они модели и наблюдениям, представленным реальными данными. Ниже приведен код описания процесса внесения пожертвований, находящегося в слабой зависимости от количества писем, открываемых членом организации в течение недели.

# %%
## Внесение пожертвований
def produce_donations(period_rng, member_behavior, num_emails,use_id, member_join_year):
    donation_amounts = np.array([0, 25, 50, 75, 100, 250, 500, 1000, 1500, 2000])
    member_has = np.random.choice(donation_amounts)
    email_fraction = num_emails/(NUM_EMAILS_SENT_WEEKLY * len(period_rng))
    member_gives = member_has * email_fraction
    member_gives_idx = np.where(member_gives >= donation_amounts) [0][-1]
    member_gives_idx = max (min (member_gives_idx, len(donation_amounts) - 2), 1)
    num_times_gave = np.random.poisson (2) * (2018 - member_join_year)
    times = np.random.randint(0, len(period_rng), num_times_gave)
    dons = pd.DataFrame ({'member': [], 'amount': [ ], 'timestamp': [ ]})
    for n in range (num_times_gave) :
        donation = donation_amounts[member_gives_idx+ np.random.binomial (1, .3)]
        ts = str(period_rng [times [n] ] .start_time + random_weekly_time_delta())
        dons = pd.concat([dons, (pd.DataFrame({'member' : [use_id],'amount' : [donation],'timestamp': [ts]}))], ignore_index=True)
        if dons. shape [0] > 0:
            dons = dons [dons. amount != 0]
## Нулевые пожертвования не указываются, поскольку
## в реальной базе данных они не регистрируются
    return dons

# %% [markdown]
# Чтобы сделать модель более реалистичной, в коде реализуются следующие важные предположения.<br>
#
# • Общая сумма пожертвований зависит от общего срока членства в организации.<br>
#
# • Каждому из членов организации назначается уровень благосостояния, с помощью которого обыгрывается предположение о том, что сумма денежного взноса напрямую зависит от суммы, которую человек готов выделить на добровольные пожертвования.<br>
#
# Поскольку поведение наших участников строго фиксируется по временным меткам, каждому члену организации нужно определить неделю и день внесения пожертвований. Напишем вспомогательную функцию выбора случайного времени в течение недели.<br>

# %%
def random_weekly_time_delta () :
    days_of_week = [d for d in range(7)]
    hours_of_day = [h for h in range(11, 23)]
    minute_of_hour = [m for m in range (60)]
    second_of_minute = [s for s in range (60)]
    return pd.Timedelta(str(np.random.choice(days_of_week)) + "days") +pd.Timedelta (str(np.random.choice(hours_of_day)) + "hours" ) +pd.Timedelta(str(np.random.choice(minute_of_hour)) + "minutes") +pd.Timedelta(str(np.random.choice(second_of_minute)) + "seconds")

# %% [markdown]
# Заметим, что в приведенном выше коде обрабатываются только часы временной метки в диапазоне от 11 до 23 (hours_of_day = [h for h in range (11, 23) ]). Предполагается, что все члены организации проживают в смежных часовых поясах или даже в общем часовом поясе, поэтому мы не обрабатываем часы вне указанного диапазона. Таким способом мы заметно ограничиваем базовую модель поведения пользователей.
#
# Итак, мы ожидаем увидеть унифицированное поведение наших пользователей, как если бы они все находились в одном или нескольких смежных часовых поясах. Кроме того, считается, что людям свойственно переводить пожертвования в дневное время — с позднего утра до позднего вечера, но не ночью и не ранним утром, сразу же после пробуждения.<br>
#
# Наконец, нам нужно объединить все компоненты модели и смоделировать поведение определенного количества членов организации и соответствующих событий, возникающих только вследствие получения членства в организации, таким образом, чтобы обеспечить некоторое (но не пренебрежимо малое) влияние событий просмотра электронной почты на события внесения пожертвований.<br>

# %%
behaviors = [never_opens,constant_open_rate,increasing_open_rate,decreasing_open_rate]
member_behaviors = np.random.choice(behaviors, 1000, [0.2, 0.5, 0.1, 0.2])
rng = pd.period_range('2015-02-14', '2018-06-01', freq = 'W')
emails = pd.DataFrame ({'member': [],'week': [ ],'emailsOpened': [ ]})
donations = pd.DataFrame({'member' : [],'amount' : [ ],'timestamp' : [ ] })
for idx in range(yearJoined.shape[0]):
## Генерирование случайного момента получения членства в организации
    join_date = pd.Timestamp(yearJoined.iloc[idx].yearJoined) + pd.Timedelta(str(np.random.randint(0, 365)) + 'days')
    join_date = min(join_date, pd.Timestamp('2018-06-01'))

## До вступления в организацию временные метки не предусмотрены
    member_rng = rng[rng.to_timestamp() > join_date]
    if len(member_rng) < 1:
        continue
    info = member_behaviors [idx] (member_rng)
    if len(info) == len (member_rng) :
        emails = pd.concat([emails, (pd.DataFrame({'member': [idx] * len(info),'week': [str(r. start_time) for r in member_rng],'emailsOpened' : info}))], ignore_index=True)
        donations = pd.concat([donations, (produce_donations(member_rng, member_behaviors[idx],sum(info), idx, join_date.year))], ignore_index = True)

# %% [markdown]
# Теперь нужно изучить временное поведение доноров, чтобы понять, как можно использовать эту информацию в дальнейшем анализе или прогнозировании.
#
# Отобразим общую сумму ежемесячных добровольных пожертвований, вычисленных из набора данных (Рис. 3.1).

# %%
df = pd.read_csv("/content/drive/MyDrive/TS&ML/Работы студентов 2024/Команда1/3/donations.csv")
df.set_index(pd.to_datetime(df.timestamp), inplace = True)
df.sort_index(inplace = True)
df.groupby(pd.Grouper(freq= 'ME')).amount.sum().plot()
# Out:
# <Axes: xlabel='timestamp'>

# %% [markdown]
# *Рис. 3.1. Общая сумма ежемесячных взносов, учитываемых в наборе данных*

# %% [markdown]
# Построив график можно увидеть, что объем пожертвований и количество открытых электронных писем увеличились с 2015 по 2018 год. Это неудивительно, поскольку за этот же период у организации прибавилось членов, о чем свидетельствует общее количество новых членов, присоединившихся к организации за учитываемые годы. Фактически одно из допущений нашей модели заключалось в том, что мы должны сохранять информацию о каждом члене неопределенный длительный период времени после его вступления в организацию. Мы не предусмотрели возможность выхода из организации, хотя и учли, что ее члены могут потерять интерес к благотворительной деятельности (отказ от просмотра электронных писем). Однако даже в этом случае за ними сохраняется возможность внесения пожертвований. Предположение о бесконечно продолжающемся членстве в организации (и коррелированном поведении пожертвований) прекрасно отображено на полученном рисунке. Таким образом, нам следует доработать код, чтобы исключить из него нереалистичный сценарий неограниченного членства и срока внесения пожертвований.<br>
# В нашем примере мы несколько отходим от классических принципов моделирования временных рядов и занимаемся скорее генерированием табличных данных. Но не нужно забывать и том, что нашей конечной целью было получение временных рядов. Поэтому генерирование табличных данных выполнялось с учетом следующих факторов и предположений.<br>
#
# • Общее количество временных рядов.<br>
#
# • Моделируемые временные тренды.<br>
#
# — В случае электронной почты мы будем придерживаться трех трендов: постоянной, растущей и падающей частот просмотра электронной почты.<br>
#
# — Внесение добровольных пожертвований считается шаблонным поведением, коррелирующим с количеством электронных писем, просматриваемым членом организации за анализируемый период времени. Это порождает упреждение, но, поскольку данные генерируются, а не собираются, таким способом описывается лояльность к организации — чем чаще просматриваются электронные письма, тем больше частота внесения пожертвований.<br>
#
# • События просмотра электронных писем и внесения пожертвований должны приниматься в расчет только после получения членства в организации.<br>
#
# • Данные не должны уходить в будущее в угоду их конечным потребителям, даже несмотря на то, что в моделировании такие данные всегда приветствуются.<br>
# Конечно, полученный нами код не идеален. Он громоздкий и не реализует модель в задуманном виде. Более того, поскольку логика модели проверялась только на программном уровне, в ней могут встречаться ошибки пограничного характера (возникновения событий в нелогической последовательности). Для предотвращения ошибок такого типа, прежде чем приступить к разработке модели, нужно выработать общие показатели и стандарты ее достоверности.<br>
# Итак, нам требуется программное обеспечение, которое сделает модель логичной и целостной. За помощью обратимся к генераторам языка Python.

# %% [markdown]
# <h2>Создание самоуправляемой среды моделирования</h2>

# %% [markdown]
# При решении многих задач от вас может потребоваться установить правила для уже имеющейся системы и понаблюдать за их соблюдением. Таким способом, например, можно проанализировать цели использования приложения широким кругом независимых пользователей или протестировать внутреннюю систему принятия решений на устойчивость к внешним воздействиям. Иными словами, вы можете отслеживать вклад отдельных агентов в совокупные показатели с течением времени. Язык Python особенно хорошо подходит для решения такого рода задач благодаря поддержке генераторов.<br>
#
# Генераторы позволяют создать серию независимых (или зависимых!) объектов и активизировать их для изучения имеющихся возможностей без написания слишком громоздкого кода отслеживания происходящих изменений.<br>
#
# В следующем примере мы будем моделировать поведение таксопарка. Попробуем представить, как функционирует таксопарк, в котором рабочие смены начинаются в разное время. Для этого создадим определенное количество виртуальных такси, отправим их в виртуальный город и заставим отчитываться о проделанной работе.<br>
#
# Такое моделирование представляет собой исключительно сложную задачу. В демонстрационных целях признаем, что будем создавать более простую среду, чем та, которая, как нам кажется, отражает действительность (не забывайте о том, что все модели неправдоподобны в той или иной степени). Начнем с изучения понятия генератора в языке Python.<br>
# Рассмотрим метод, используемый мною для получения идентификационного номера такси.<br>

# %%
def taxi_id_number(num_taxis):
    arr = np.arange(num_taxis)
    np.random.shuffle(arr)
    for i in range(num_taxis) :
        yield arr[i]

ids = taxi_id_number(10)
print (next (ids))
print (next (ids))
print (next (ids))
# Out:
# 9
# 1
# 5

# %% [markdown]
# Числа повторяются до тех пор, пока их не станет 10, после чего реализуется выход из цикла for по исключению StopIteration.<br>
#
# Функция taxi_id_number () создает разовые объекты, не зависящие друг от друга, но сохраняющие сведения о состоянии ее выполнения. Это функция-генератор. Вы можете рассматривать генераторы как небольшие объекты, снабженные специальными переменными состояния, которые оказываются незаменимыми при создании множества схожих объектов с собственными значениями таких переменных.<br>
#
# В задаче моделирования таксопарка разделим подвижной состав такси на смены, индикация которых выполняется с помощью генератора. Предполагается, что в середине дня на маршруты выезжает больше машин, чем в вечерние или ночные смены, определяемые разными вероятностями начала смены в указанные моменты времени.<br>

# %%
def shift_info () :
    start_times_and_freqs = [(0, 8), (8, 30), (16, 15)]
    indices = np.arange(len(start_times_and_freqs))
    while True:
        idx = np.random.choice (indices, p = [0.25, 0.5, 0.25])
        start = start_times_and_freqs[idx]
        yield (start[0], start[0] + 7.5, start [1])

# %% [markdown]
# Обратите внимание на переменную start times and freqs. С ее определения начинается моделирование временного ряда. В нем указываем, что вероятность выхода такси на маршрут зависит от времени суток. Кроме того, каждому времени суток сопоставляется свое среднее количество поездок. Перейдем к написанию более сложного генератора, в котором предыдущие генераторы используются для установки индивидуальных параметров и расписания такси.<br>

# %%
def taxi_process(taxi_id_generator, shift_info_generator) :
    taxi_id = next(taxi_id_generator)
    shift_start, shift_end, shift_mean_trips = next(shift_info_generator)
    actual_trips = round(np.random.normal (loc = shift_mean_trips, scale = 2))
    average_trip_time = 6.5/shift_mean_trips*60
# Среднее время поездки в минутах
    between_events_time = 1.0/(shift_mean_trips - 1)*60
# Город, в котором такси освобождается от клиента
    time = shift_start
    yield TimePoint(taxi_id, 'start shift', time)
    deltaT = np.random.poisson(between_events_time) / 630
    time += deltaT
    for i in range (actual_trips) :
        yield TimePoint(taxi_id, 'pick up', time)
        deltaT = np.random.poisson(average_trip_time) / 60
        time += deltaT
        yield TimePoint(taxi_id, 'drop off', time)
        deltaT = np.random.poisson(between_events_time) / 60
        time += deltaT
    deltaT = np.random.poisson(between_events_time) / 60
    time += deltaT
    yield TimePoint (taxi_id, 'end shift ', time)

# %% [markdown]
# Здесь с помощью генераторов сначала определяются идентификационный номер такси, время начала смены и среднее количество поездок.<br>
#
# После этого такси отправляется по маршруту, выполняя по сформированному для него расписанию определенное количество поездок, каждая из которых совершается для следующего клиента по вызову функции next () из генератора.<br>
#
# По сути, этот генератор создает временные ряды данных для отдельного такси. Генератор такси возвращает объекты класса TimePoint, которые определяются следующим образом.<br>

# %%
from dataclasses import dataclass
@dataclass
class TimePoint:
    taxi_id: int
    name: str
    time: float

    def __lt__ (self, other) :
         return self.time < other.time

# %% [markdown]
# Для упрощения кода в нем используется декоратор dataclass() (требуется Python 3.7). Настоятельно рекомендуется ознакомиться с возможностями этого вспомогательного инструмента языка Python всем заинтересованным анализом и обработкой данных, применяющим его в своих проектах.<br>
#
# Магические методы в Python Магические (или дандер) методы в языке Python, имена которых начинаются и заканчиваются двойным подчеркиванием, представляют собой встроенные методы, характерные для целевого класса. Такие методы вызываются автоматически при обращении к соответствующему объекту. Существуют реализации таких методов, которые могут быть переопределены при ручном задании для класса. Существует ряд причин, по которым вы можете захотеть сделать это. Например, в предыдущем коде нужно, чтобы сравнение объектов класса TimePoints выполнялось только по времени, но не по атрибуту taxi id или name. Термин “дандер” (dunder) происходит от “double under” (двойное подчеркивание).<br>
#
# Кроме автоматически сгенерированного инициализатора класса TimePoint, нам понадобятся два других, более сложных метода:__ It__ (сравнение объектов класса TimePoints) и__ str__ (вывод объектов класса TimePoints, не реализованный здесь). Сравнение необходимо, поскольку сгенерированные в процессе моделирования временные точки объединяются в общую структуру данных, в которых они хранятся в определенном порядке — в очереди по приоритету. Очередь по приоритету — это абстрактный тип данных, в который объекты можно добавлять в любом порядке, но в котором они выстраиваются в порядке, устанавливаемом их приоритетом.<br>
#
# Абстрактный тип данных — это вычислительная модель, определяемая поведением, которая характеризуется заранее оговоренным набором действий и входных данных, а также результатами применения таких действий к определенным наборам данных. Пример общеизвестного абстрактного типа данных — FIFO (“первым пришел — первым обслужен”). В нем объекты извлекаются из структуры данных в том же порядке, в котором были в нее добавлены. Способы достижения такого принципа зависят от методов реализации, а не от его определения.<br>
#
# Итак, мы располагаем классом моделирования для настройки и запуска генераторов такси. Это нестандартный класс, поскольку обладает специальными функциями — в том числе заданными в инициализаторе — представления входных данных в виде понятной структуры данных и дальнейшей их обработки. Заметьте, что при этом единственной общедоступной является функция **run()**.<br>

# %%
import queue

class Simulator:
    def __init__(self, num_taxis) :
        self.time_points = queue.PriorityQueue()
        taxi_id_generator = taxi_id_number(num_taxis)
        shift_info_generator = shift_info()
        self.taxis = [taxi_process(taxi_id_generator,shift_info_generator) for i in range(num_taxis)]
        self.prepare_run()

    def prepare_run(self) :
        for t in self.taxis:
            while True:
                try:
                    e = next(t)
                    self.time_points.put(e)
                except StopIteration:
                    break

    def run(self) :
        sim_time = 0
        while sim_time < 24:
            if self.time_points.empty():
                break
            p = self.time_points.get()
            sim_time = p.time
            print(p)

# %% [markdown]
# Сначала в коде создается точно такое количество генераторов, какое требуется для моделирования заданного числа машин такси. Затем совершается проход по каждому такси, связанному с классом TimePoints, в результате которого все объекты класса TimePoints располагаются в порядке приоритетности. В пользовательском классе, таком как TimePoint, приоритет объекта определяется в его инициализаторе __ lt __ сравнением текущей временной точки с начальной точкой. Таким образом, при размещении согласно приоритетности, объекты класса TimePoints упорядочиваются по времени их создания. Процесс моделирования запускается с помощью следующих команд.

# %%
sim = Simulator(1000)
sim.run()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# TimePoint(taxi_id=875, name='drop off', time=18.954761904761902)
# TimePoint(taxi_id=526, name='drop off', time=18.954761904761906)
# TimePoint(taxi_id=570, name='drop off', time=18.95476190476191)
# TimePoint(taxi_id=408, name='drop off', time=18.95476190476191)
# TimePoint(taxi_id=358, name='drop off', time=18.954761904761913)
# TimePoint(taxi_id=128, name='pick up', time=18.954761904761913)
# TimePoint(taxi_id=427, name='drop off', time=18.954761904761913)
# TimePoint(taxi_id=497, name='drop off', time=18.956349206349202)
# TimePoint(taxi_id=459, name='drop off', time=18.956349206349202)
# TimePoint(taxi_id=788, name='pick up', time=18.95634920634921)
# TimePoint(taxi_id=123, name='drop off', time=18.95634920634921)
# TimePoint(taxi_id=438, name='pick up', time=18.957936507936516)
# TimePoint(taxi_id=385, name='drop off', time=18.957936507936516)
# TimePoint(taxi_id=631, name='pick up', time=18.957936507936516)
# TimePoint(taxi_id=107, name='drop off', time=18.95952380952381)
# TimePoint(taxi_id=53, name='drop off', time=18.95952380952381)
# TimePoint(taxi_id=975, name='pick up', time=18.959523809523812)
# TimePoint(taxi_id=183, name='pick up', time=18.959523809523812)
# TimePoint(taxi_id=512, name='pick up', time=18.959523809523812)
# TimePoint(taxi_id=73, name='pick up', time=18.961111111111116)
# TimePoint(taxi_id=880, name='drop off', time=18.96825396825397)
# TimePoint(taxi_id=969, name='drop off', time=18.96984126984127)
# TimePoint(taxi_id=169, name='drop off', time=18.969841269841275)
# TimePoint(taxi_id=270, name='pick up', time=18.97142857142857)
# TimePoint(taxi_id=112, name='drop off', time=18.97142857142857)
# TimePoint(taxi_id=3, name='drop off', time=18.97142857142857)
# TimePoint(taxi_id=803, name='pick up', time=18.971428571428575)
# TimePoint(taxi_id=358, name='pick up', time=18.97142857142858)
# TimePoint(taxi_id=115, name='pick up', time=18.97301587301587)
# TimePoint(taxi_id=963, name='drop off', time=18.973015873015875)
# TimePoint(taxi_id=516, name='drop off', time=18.973015873015875)
# TimePoint(taxi_id=709, name='drop off', time=18.974603174603175)
# TimePoint(taxi_id=709, name='pick up', time=18.974603174603175)
# TimePoint(taxi_id=815, name='drop off', time=18.97460317460318)
# TimePoint(taxi_id=429, name='pick up', time=18.974603174603182)
# TimePoint(taxi_id=130, name='drop off', time=18.97619047619047)
# TimePoint(taxi_id=445, name='drop off', time=18.980952380952385)
# TimePoint(taxi_id=156, name='drop off', time=18.984920634920634)
# TimePoint(taxi_id=759, name='pick up', time=18.984920634920638)
# TimePoint(taxi_id=235, name='drop off', time=18.984920634920638)
# TimePoint(taxi_id=913, name='drop off', time=18.98492063492064)
# TimePoint(taxi_id=89, name='pick up', time=18.986507936507934)
# TimePoint(taxi_id=922, name='pick up', time=18.986507936507937)
# TimePoint(taxi_id=858, name='pick up', time=18.986507936507937)
# TimePoint(taxi_id=208, name='drop off', time=18.986507936507937)
# TimePoint(taxi_id=126, name='drop off', time=18.98650793650794)
# TimePoint(taxi_id=526, name='pick up', time=18.98809523809524)
# TimePoint(taxi_id=394, name='pick up', time=18.989682539682534)
# TimePoint(taxi_id=500, name='pick up', time=18.98968253968254)
# TimePoint(taxi_id=66, name='drop off', time=18.99126984126984)
# TimePoint(taxi_id=589, name='pick up', time=18.99285714285714)
# TimePoint(taxi_id=533, name='pick up', time=18.992857142857144)
# TimePoint(taxi_id=43, name='drop off', time=19.001587301587307)
# TimePoint(taxi_id=112, name='pick up', time=19.004761904761907)
# TimePoint(taxi_id=642, name='pick up', time=19.004761904761907)
# TimePoint(taxi_id=177, name='drop off', time=19.004761904761907)
# TimePoint(taxi_id=25, name='pick up', time=19.00634920634921)
# TimePoint(taxi_id=752, name='drop off', time=19.00634920634921)
# TimePoint(taxi_id=871, name='pick up', time=19.00793650793651)
# TimePoint(taxi_id=130, name='pick up', time=19.009523809523806)
# TimePoint(taxi_id=107, name='pick up', time=19.00952380952381)
# TimePoint(taxi_id=321, name='drop off', time=19.00952380952381)
# TimePoint(taxi_id=575, name='drop off', time=19.00952380952381)
# TimePoint(taxi_id=995, name='pick up', time=19.01111111111111)
# TimePoint(taxi_id=396, name='pick up', time=19.01111111111111)
# TimePoint(taxi_id=125, name='drop off', time=19.011111111111113)
# TimePoint(taxi_id=846, name='pick up', time=19.011111111111113)
# TimePoint(taxi_id=272, name='drop off', time=19.01111111111112)
# TimePoint(taxi_id=640, name='drop off', time=19.015873015873016)
# TimePoint(taxi_id=122, name='pick up', time=19.017460317460323)
# TimePoint(taxi_id=469, name='drop off', time=19.019841269841265)
# TimePoint(taxi_id=329, name='pick up', time=19.01984126984127)
# TimePoint(taxi_id=208, name='pick up', time=19.019841269841272)
# TimePoint(taxi_id=875, name='pick up', time=19.02142857142857)
# TimePoint(taxi_id=677, name='pick up', time=19.02142857142857)
# TimePoint(taxi_id=408, name='pick up', time=19.021428571428576)
# TimePoint(taxi_id=212, name='pick up', time=19.02142857142858)
# TimePoint(taxi_id=459, name='pick up', time=19.02301587301587)
# TimePoint(taxi_id=513, name='drop off', time=19.023015873015876)
# TimePoint(taxi_id=76, name='drop off', time=19.02460317460317)
# TimePoint(taxi_id=622, name='drop off', time=19.024603174603172)
# TimePoint(taxi_id=888, name='drop off', time=19.02619047619048)
# TimePoint(taxi_id=156, name='pick up', time=19.034920634920635)
# TimePoint(taxi_id=646, name='pick up', time=19.034920634920635)
# TimePoint(taxi_id=880, name='pick up', time=19.034920634920635)
# TimePoint(taxi_id=992, name='drop off', time=19.03492063492064)
# TimePoint(taxi_id=627, name='pick up', time=19.03492063492064)
# TimePoint(taxi_id=169, name='pick up', time=19.03650793650794)
# TimePoint(taxi_id=656, name='drop off', time=19.03809523809524)
# TimePoint(taxi_id=497, name='pick up', time=19.039682539682534)
# TimePoint(taxi_id=423, name='drop off', time=19.039682539682538)
# TimePoint(taxi_id=123, name='pick up', time=19.03968253968254)
# TimePoint(taxi_id=773, name='drop off', time=19.03968253968254)
# TimePoint(taxi_id=529, name='drop off', time=19.03968253968254)
# TimePoint(taxi_id=303, name='drop off', time=19.039682539682545)
# TimePoint(taxi_id=754, name='drop off', time=19.039682539682545)
# TimePoint(taxi_id=301, name='pick up', time=19.041269841269838)
# TimePoint(taxi_id=15, name='drop off', time=19.04126984126984)
# TimePoint(taxi_id=385, name='pick up', time=19.04126984126985)
# TimePoint(taxi_id=621, name='drop off', time=19.04126984126985)
# TimePoint(taxi_id=53, name='pick up', time=19.04285714285714)
# TimePoint(taxi_id=39, name='drop off', time=19.04285714285714)
# TimePoint(taxi_id=275, name='drop off', time=19.042857142857144)
# TimePoint(taxi_id=577, name='pick up', time=19.042857142857148)
# TimePoint(taxi_id=322, name='drop off', time=19.046031746031755)
# TimePoint(taxi_id=532, name='drop off', time=19.04920634920635)
# TimePoint(taxi_id=779, name='pick up', time=19.04920634920635)
# TimePoint(taxi_id=913, name='pick up', time=19.051587301587308)
# TimePoint(taxi_id=43, name='pick up', time=19.051587301587308)
# TimePoint(taxi_id=460, name='pick up', time=19.053174603174604)
# TimePoint(taxi_id=345, name='drop off', time=19.053174603174604)
# TimePoint(taxi_id=30, name='drop off', time=19.053174603174604)
# TimePoint(taxi_id=957, name='drop off', time=19.054761904761907)
# TimePoint(taxi_id=220, name='drop off', time=19.0563492063492)
# TimePoint(taxi_id=516, name='pick up', time=19.056349206349207)
# TimePoint(taxi_id=754, name='pick up', time=19.05634920634921)
# TimePoint(taxi_id=66, name='pick up', time=19.057936507936507)
# TimePoint(taxi_id=630, name='drop off', time=19.05793650793651)
# TimePoint(taxi_id=428, name='drop off', time=19.05793650793651)
# TimePoint(taxi_id=321, name='pick up', time=19.05952380952381)
# TimePoint(taxi_id=79, name='drop off', time=19.05952380952381)
# TimePoint(taxi_id=373, name='drop off', time=19.05952380952381)
# TimePoint(taxi_id=568, name='drop off', time=19.059523809523814)
# TimePoint(taxi_id=654, name='drop off', time=19.059523809523814)
# TimePoint(taxi_id=219, name='drop off', time=19.06111111111111)
# TimePoint(taxi_id=694, name='drop off', time=19.062698412698417)
# TimePoint(taxi_id=807, name='drop off', time=19.062698412698417)
# TimePoint(taxi_id=445, name='pick up', time=19.064285714285717)
# TimePoint(taxi_id=153, name='drop off', time=19.067460317460316)
# TimePoint(taxi_id=886, name='drop off', time=19.06825396825397)
# TimePoint(taxi_id=235, name='pick up', time=19.06825396825397)
# TimePoint(taxi_id=992, name='pick up', time=19.068253968253973)
# TimePoint(taxi_id=469, name='pick up', time=19.069841269841266)
# TimePoint(taxi_id=333, name='drop off', time=19.069841269841273)
# TimePoint(taxi_id=670, name='drop off', time=19.07142857142857)
# TimePoint(taxi_id=652, name='drop off', time=19.071428571428573)
# TimePoint(taxi_id=109, name='drop off', time=19.07142857142858)
# TimePoint(taxi_id=592, name='drop off', time=19.073015873015873)
# TimePoint(taxi_id=74, name='drop off', time=19.073015873015876)
# TimePoint(taxi_id=752, name='pick up', time=19.073015873015876)
# TimePoint(taxi_id=622, name='pick up', time=19.074603174603173)
# TimePoint(taxi_id=398, name='pick up', time=19.07460317460318)
# TimePoint(taxi_id=398, name='drop off', time=19.07460317460318)
# TimePoint(taxi_id=878, name='drop off', time=19.076190476190476)
# TimePoint(taxi_id=618, name='drop off', time=19.076190476190476)
# TimePoint(taxi_id=888, name='pick up', time=19.07619047619048)
# TimePoint(taxi_id=654, name='pick up', time=19.07619047619048)
# TimePoint(taxi_id=125, name='pick up', time=19.07777777777778)
# TimePoint(taxi_id=300, name='drop off', time=19.08650793650793)
# TimePoint(taxi_id=563, name='drop off', time=19.086507936507935)
# TimePoint(taxi_id=969, name='pick up', time=19.08650793650794)
# TimePoint(taxi_id=345, name='pick up', time=19.08650793650794)
# TimePoint(taxi_id=3, name='pick up', time=19.08809523809524)
# TimePoint(taxi_id=177, name='pick up', time=19.08809523809524)
# TimePoint(taxi_id=570, name='pick up', time=19.088095238095242)
# TimePoint(taxi_id=418, name='pick up', time=19.088095238095242)
# TimePoint(taxi_id=896, name='drop off', time=19.088095238095242)
# TimePoint(taxi_id=418, name='drop off', time=19.088095238095242)
# TimePoint(taxi_id=427, name='pick up', time=19.088095238095246)
# TimePoint(taxi_id=475, name='drop off', time=19.089682539682535)
# TimePoint(taxi_id=139, name='drop off', time=19.089682539682542)
# TimePoint(taxi_id=963, name='pick up', time=19.089682539682542)
# TimePoint(taxi_id=815, name='pick up', time=19.091269841269845)
# TimePoint(taxi_id=511, name='drop off', time=19.091269841269845)
# TimePoint(taxi_id=194, name='drop off', time=19.092857142857138)
# TimePoint(taxi_id=618, name='pick up', time=19.09285714285714)
# TimePoint(taxi_id=575, name='pick up', time=19.09285714285714)
# TimePoint(taxi_id=322, name='pick up', time=19.096031746031755)
# TimePoint(taxi_id=640, name='pick up', time=19.099206349206348)
# TimePoint(taxi_id=532, name='pick up', time=19.09920634920635)
# TimePoint(taxi_id=554, name='drop off', time=19.1015873015873)
# TimePoint(taxi_id=856, name='drop off', time=19.104761904761908)
# TimePoint(taxi_id=257, name='drop off', time=19.10476190476191)
# TimePoint(taxi_id=303, name='pick up', time=19.10634920634921)
# TimePoint(taxi_id=76, name='pick up', time=19.1079365079365)
# TimePoint(taxi_id=685, name='drop off', time=19.107936507936504)
# TimePoint(taxi_id=287, name='drop off', time=19.107936507936508)
# TimePoint(taxi_id=613, name='drop off', time=19.107936507936508)
# TimePoint(taxi_id=15, name='pick up', time=19.107936507936508)
# TimePoint(taxi_id=793, name='drop off', time=19.10793650793651)
# TimePoint(taxi_id=98, name='drop off', time=19.107936507936515)
# TimePoint(taxi_id=468, name='drop off', time=19.109523809523807)
# TimePoint(taxi_id=160, name='drop off', time=19.11111111111111)
# TimePoint(taxi_id=510, name='drop off', time=19.111111111111118)
# TimePoint(taxi_id=807, name='pick up', time=19.112698412698418)
# TimePoint(taxi_id=633, name='drop off', time=19.116666666666664)
# TimePoint(taxi_id=868, name='drop off', time=19.116666666666667)
# TimePoint(taxi_id=600, name='drop off', time=19.11666666666667)
# TimePoint(taxi_id=326, name='drop off', time=19.11825396825397)
# TimePoint(taxi_id=652, name='pick up', time=19.121428571428574)
# TimePoint(taxi_id=783, name='drop off', time=19.121428571428577)
# TimePoint(taxi_id=220, name='pick up', time=19.123015873015866)
# TimePoint(taxi_id=597, name='drop off', time=19.12301587301587)
# TimePoint(taxi_id=423, name='pick up', time=19.12301587301587)
# TimePoint(taxi_id=529, name='pick up', time=19.123015873015873)
# TimePoint(taxi_id=513, name='pick up', time=19.123015873015877)
# TimePoint(taxi_id=630, name='pick up', time=19.124603174603177)
# TimePoint(taxi_id=511, name='pick up', time=19.12460317460318)
# TimePoint(taxi_id=623, name='drop off', time=19.124603174603184)
# TimePoint(taxi_id=878, name='pick up', time=19.126190476190477)
# TimePoint(taxi_id=272, name='pick up', time=19.127777777777787)
# TimePoint(taxi_id=918, name='drop off', time=19.129365079365087)
# TimePoint(taxi_id=600, name='pick up', time=19.133333333333336)
# TimePoint(taxi_id=153, name='pick up', time=19.134126984126983)
# TimePoint(taxi_id=886, name='pick up', time=19.134920634920636)
# TimePoint(taxi_id=563, name='pick up', time=19.136507936507936)
# TimePoint(taxi_id=607, name='drop off', time=19.136507936507936)
# TimePoint(taxi_id=899, name='drop off', time=19.138095238095236)
# TimePoint(taxi_id=132, name='drop off', time=19.138095238095236)
# TimePoint(taxi_id=899, name='pick up', time=19.138095238095236)
# TimePoint(taxi_id=825, name='drop off', time=19.138095238095243)
# TimePoint(taxi_id=109, name='pick up', time=19.138095238095246)
# TimePoint(taxi_id=168, name='drop off', time=19.139682539682536)
# TimePoint(taxi_id=810, name='drop off', time=19.139682539682543)
# TimePoint(taxi_id=773, name='pick up', time=19.139682539682543)
# TimePoint(taxi_id=947, name='drop off', time=19.139682539682543)
# TimePoint(taxi_id=74, name='pick up', time=19.139682539682543)
# TimePoint(taxi_id=287, name='pick up', time=19.141269841269843)
# TimePoint(taxi_id=146, name='drop off', time=19.141269841269843)
# TimePoint(taxi_id=519, name='drop off', time=19.141269841269846)
# TimePoint(taxi_id=621, name='pick up', time=19.14126984126985)
# TimePoint(taxi_id=602, name='drop off', time=19.142857142857142)
# TimePoint(taxi_id=79, name='pick up', time=19.142857142857142)
# TimePoint(taxi_id=39, name='pick up', time=19.142857142857142)
# TimePoint(taxi_id=568, name='pick up', time=19.142857142857146)
# TimePoint(taxi_id=275, name='pick up', time=19.142857142857146)
# TimePoint(taxi_id=219, name='pick up', time=19.144444444444442)
# TimePoint(taxi_id=893, name='drop off', time=19.153174603174598)
# TimePoint(taxi_id=126, name='pick up', time=19.15317460317461)
# TimePoint(taxi_id=809, name='drop off', time=19.15476190476191)
# TimePoint(taxi_id=896, name='pick up', time=19.15476190476191)
# TimePoint(taxi_id=856, name='pick up', time=19.15476190476191)
# TimePoint(taxi_id=656, name='pick up', time=19.15476190476191)
# TimePoint(taxi_id=957, name='pick up', time=19.15476190476191)
# TimePoint(taxi_id=475, name='pick up', time=19.1563492063492)
# TimePoint(taxi_id=592, name='pick up', time=19.156349206349205)
# TimePoint(taxi_id=802, name='drop off', time=19.15634920634921)
# TimePoint(taxi_id=139, name='pick up', time=19.15634920634921)
# TimePoint(taxi_id=960, name='drop off', time=19.157936507936505)
# TimePoint(taxi_id=309, name='drop off', time=19.157936507936512)
# TimePoint(taxi_id=910, name='drop off', time=19.157936507936515)
# TimePoint(taxi_id=336, name='drop off', time=19.15793650793652)
# TimePoint(taxi_id=354, name='drop off', time=19.16111111111111)
# TimePoint(taxi_id=520, name='drop off', time=19.164285714285715)
# TimePoint(taxi_id=868, name='pick up', time=19.166666666666668)
# TimePoint(taxi_id=406, name='drop off', time=19.167460317460325)
# TimePoint(taxi_id=956, name='drop off', time=19.16825396825398)
# TimePoint(taxi_id=171, name='drop off', time=19.169841269841267)
# TimePoint(taxi_id=203, name='drop off', time=19.16984126984127)
# TimePoint(taxi_id=607, name='pick up', time=19.16984126984127)
# TimePoint(taxi_id=282, name='drop off', time=19.169841269841275)
# TimePoint(taxi_id=731, name='drop off', time=19.171428571428574)
# TimePoint(taxi_id=916, name='drop off', time=19.17301587301587)
# TimePoint(taxi_id=937, name='drop off', time=19.174603174603178)
# TimePoint(taxi_id=21, name='drop off', time=19.17460317460318)
# TimePoint(taxi_id=373, name='pick up', time=19.176190476190477)
# TimePoint(taxi_id=602, name='pick up', time=19.176190476190477)
# TimePoint(taxi_id=290, name='drop off', time=19.177777777777777)
# TimePoint(taxi_id=510, name='pick up', time=19.177777777777784)
# TimePoint(taxi_id=633, name='pick up', time=19.18333333333333)
# TimePoint(taxi_id=554, name='pick up', time=19.184920634920633)
# TimePoint(taxi_id=300, name='pick up', time=19.186507936507933)
# TimePoint(taxi_id=30, name='pick up', time=19.186507936507937)
# TimePoint(taxi_id=670, name='pick up', time=19.188095238095237)
# TimePoint(taxi_id=731, name='pick up', time=19.18809523809524)
# TimePoint(taxi_id=61, name='drop off', time=19.189682539682536)
# TimePoint(taxi_id=168, name='pick up', time=19.189682539682536)
# TimePoint(taxi_id=147, name='drop off', time=19.18968253968254)
# TimePoint(taxi_id=802, name='pick up', time=19.189682539682543)
# TimePoint(taxi_id=810, name='pick up', time=19.189682539682543)
# TimePoint(taxi_id=812, name='drop off', time=19.191269841269843)
# TimePoint(taxi_id=40, name='drop off', time=19.191269841269843)
# TimePoint(taxi_id=114, name='drop off', time=19.191269841269847)
# TimePoint(taxi_id=194, name='pick up', time=19.19285714285714)
# TimePoint(taxi_id=468, name='pick up', time=19.19285714285714)
# TimePoint(taxi_id=739, name='drop off', time=19.192857142857143)
# TimePoint(taxi_id=160, name='pick up', time=19.194444444444443)
# TimePoint(taxi_id=313, name='drop off', time=19.194444444444446)
# TimePoint(taxi_id=694, name='pick up', time=19.19603174603175)
# TimePoint(taxi_id=734, name='drop off', time=19.197619047619053)
# TimePoint(taxi_id=760, name='drop off', time=19.201587301587303)
# TimePoint(taxi_id=619, name='drop off', time=19.201587301587306)
# TimePoint(taxi_id=274, name='drop off', time=19.203174603174602)
# TimePoint(taxi_id=203, name='pick up', time=19.203174603174606)
# TimePoint(taxi_id=333, name='pick up', time=19.203174603174606)
# TimePoint(taxi_id=282, name='pick up', time=19.20317460317461)
# TimePoint(taxi_id=783, name='pick up', time=19.20476190476191)
# TimePoint(taxi_id=809, name='pick up', time=19.20476190476191)
# TimePoint(taxi_id=825, name='pick up', time=19.20476190476191)
# TimePoint(taxi_id=257, name='pick up', time=19.204761904761913)
# TimePoint(taxi_id=824, name='drop off', time=19.206349206349206)
# TimePoint(taxi_id=350, name='drop off', time=19.206349206349206)
# TimePoint(taxi_id=947, name='pick up', time=19.20634920634921)
# TimePoint(taxi_id=685, name='pick up', time=19.207936507936505)
# TimePoint(taxi_id=428, name='pick up', time=19.20793650793651)
# TimePoint(taxi_id=793, name='pick up', time=19.207936507936513)
# TimePoint(taxi_id=937, name='pick up', time=19.207936507936513)
# TimePoint(taxi_id=623, name='pick up', time=19.207936507936516)
# TimePoint(taxi_id=710, name='drop off', time=19.209523809523805)
# TimePoint(taxi_id=628, name='drop off', time=19.209523809523812)
# TimePoint(taxi_id=403, name='drop off', time=19.209523809523812)
# TimePoint(taxi_id=782, name='drop off', time=19.211111111111112)
# TimePoint(taxi_id=520, name='pick up', time=19.214285714285715)
# TimePoint(taxi_id=132, name='pick up', time=19.221428571428568)
# TimePoint(taxi_id=556, name='drop off', time=19.221428571428575)
# TimePoint(taxi_id=887, name='drop off', time=19.221428571428575)
# TimePoint(taxi_id=895, name='drop off', time=19.221428571428582)
# TimePoint(taxi_id=688, name='drop off', time=19.221428571428582)
# TimePoint(taxi_id=61, name='pick up', time=19.22301587301587)
# TimePoint(taxi_id=808, name='drop off', time=19.223015873015875)
# TimePoint(taxi_id=213, name='drop off', time=19.224603174603175)
# TimePoint(taxi_id=146, name='pick up', time=19.224603174603175)
# TimePoint(taxi_id=447, name='drop off', time=19.224603174603175)
# TimePoint(taxi_id=309, name='pick up', time=19.22460317460318)
# TimePoint(taxi_id=40, name='pick up', time=19.22460317460318)
# TimePoint(taxi_id=737, name='drop off', time=19.22460317460318)
# TimePoint(taxi_id=812, name='pick up', time=19.22460317460318)
# TimePoint(taxi_id=519, name='pick up', time=19.22460317460318)
# TimePoint(taxi_id=98, name='pick up', time=19.224603174603182)
# TimePoint(taxi_id=710, name='pick up', time=19.22619047619047)
# TimePoint(taxi_id=626, name='drop off', time=19.22619047619048)
# TimePoint(taxi_id=734, name='pick up', time=19.230952380952388)
# TimePoint(taxi_id=406, name='pick up', time=19.23412698412699)
# TimePoint(taxi_id=326, name='pick up', time=19.234920634920638)
# TimePoint(taxi_id=956, name='pick up', time=19.234920634920645)
# TimePoint(taxi_id=893, name='pick up', time=19.23650793650793)
# TimePoint(taxi_id=269, name='drop off', time=19.236507936507937)
# TimePoint(taxi_id=835, name='drop off', time=19.23650793650794)
# TimePoint(taxi_id=28, name='drop off', time=19.23650793650794)
# TimePoint(taxi_id=434, name='drop off', time=19.23809523809524)
# TimePoint(taxi_id=67, name='drop off', time=19.238095238095248)
# TimePoint(taxi_id=824, name='pick up', time=19.23968253968254)
# TimePoint(taxi_id=680, name='drop off', time=19.23968253968254)
# TimePoint(taxi_id=931, name='drop off', time=19.239682539682544)
# TimePoint(taxi_id=960, name='pick up', time=19.241269841269837)
# TimePoint(taxi_id=613, name='pick up', time=19.24126984126984)
# TimePoint(taxi_id=298, name='drop off', time=19.241269841269848)
# TimePoint(taxi_id=910, name='pick up', time=19.241269841269848)
# TimePoint(taxi_id=476, name='drop off', time=19.24285714285714)
# TimePoint(taxi_id=612, name='drop off', time=19.242857142857144)
# TimePoint(taxi_id=290, name='pick up', time=19.244444444444444)
# TimePoint(taxi_id=354, name='pick up', time=19.244444444444444)
# TimePoint(taxi_id=435, name='drop off', time=19.244444444444447)
# TimePoint(taxi_id=224, name='drop off', time=19.244444444444447)
# TimePoint(taxi_id=135, name='drop off', time=19.24444444444445)
# TimePoint(taxi_id=918, name='pick up', time=19.246031746031754)
# TimePoint(taxi_id=171, name='pick up', time=19.2531746031746)
# TimePoint(taxi_id=660, name='drop off', time=19.253174603174603)
# TimePoint(taxi_id=895, name='pick up', time=19.254761904761917)
# TimePoint(taxi_id=916, name='pick up', time=19.256349206349203)
# TimePoint(taxi_id=597, name='pick up', time=19.256349206349203)
# TimePoint(taxi_id=739, name='pick up', time=19.25952380952381)
# TimePoint(taxi_id=628, name='pick up', time=19.259523809523813)
# TimePoint(taxi_id=828, name='drop off', time=19.259523809523813)
# TimePoint(taxi_id=73, name='drop off', time=19.261111111111116)
# TimePoint(taxi_id=502, name='drop off', time=19.264285714285716)
# TimePoint(taxi_id=274, name='pick up', time=19.26984126984127)
# TimePoint(taxi_id=28, name='pick up', time=19.269841269841276)
# TimePoint(taxi_id=200, name='drop off', time=19.27142857142857)
# TimePoint(taxi_id=912, name='drop off', time=19.271428571428576)
# TimePoint(taxi_id=853, name='drop off', time=19.271428571428576)
# TimePoint(taxi_id=493, name='drop off', time=19.273015873015872)
# TimePoint(taxi_id=719, name='drop off', time=19.273015873015876)
# TimePoint(taxi_id=447, name='pick up', time=19.274603174603175)
# TimePoint(taxi_id=114, name='pick up', time=19.27460317460318)
# TimePoint(taxi_id=21, name='pick up', time=19.274603174603183)
# TimePoint(taxi_id=298, name='pick up', time=19.274603174603183)
# TimePoint(taxi_id=403, name='pick up', time=19.27619047619048)
# TimePoint(taxi_id=626, name='pick up', time=19.276190476190482)
# TimePoint(taxi_id=452, name='drop off', time=19.277777777777782)
# TimePoint(taxi_id=73, name='pick up', time=19.277777777777782)
# TimePoint(taxi_id=775, name='drop off', time=19.279365079365082)
# TimePoint(taxi_id=590, name='drop off', time=19.279365079365085)
# TimePoint(taxi_id=703, name='drop off', time=19.28492063492064)
# TimePoint(taxi_id=929, name='drop off', time=19.286507936507935)
# TimePoint(taxi_id=835, name='pick up', time=19.28650793650794)
# TimePoint(taxi_id=267, name='drop off', time=19.288095238095238)
# TimePoint(taxi_id=205, name='drop off', time=19.28809523809524)
# TimePoint(taxi_id=556, name='pick up', time=19.28809523809524)
# TimePoint(taxi_id=666, name='drop off', time=19.288095238095245)
# TimePoint(taxi_id=470, name='drop off', time=19.289682539682534)
# TimePoint(taxi_id=859, name='drop off', time=19.289682539682538)
# TimePoint(taxi_id=147, name='pick up', time=19.28968253968254)
# TimePoint(taxi_id=808, name='pick up', time=19.28968253968254)
# TimePoint(taxi_id=968, name='drop off', time=19.28968253968254)
# TimePoint(taxi_id=931, name='pick up', time=19.289682539682545)
# TimePoint(taxi_id=737, name='pick up', time=19.291269841269845)
# TimePoint(taxi_id=432, name='drop off', time=19.29126984126985)
# TimePoint(taxi_id=336, name='pick up', time=19.291269841269852)
# TimePoint(taxi_id=617, name='drop off', time=19.292857142857144)
# TimePoint(taxi_id=244, name='drop off', time=19.294444444444448)
# TimePoint(taxi_id=458, name='drop off', time=19.297619047619047)
# TimePoint(taxi_id=439, name='drop off', time=19.29920634920635)
# TimePoint(taxi_id=122, name='drop off', time=19.300793650793658)
# TimePoint(taxi_id=760, name='pick up', time=19.301587301587304)
# TimePoint(taxi_id=269, name='pick up', time=19.303174603174604)
# TimePoint(taxi_id=977, name='drop off', time=19.304761904761904)
# TimePoint(taxi_id=795, name='drop off', time=19.304761904761904)
# TimePoint(taxi_id=434, name='pick up', time=19.304761904761907)
# TimePoint(taxi_id=261, name='drop off', time=19.304761904761907)
# TimePoint(taxi_id=358, name='drop off', time=19.30476190476191)
# TimePoint(taxi_id=688, name='pick up', time=19.304761904761914)
# TimePoint(taxi_id=394, name='drop off', time=19.3063492063492)
# TimePoint(taxi_id=840, name='drop off', time=19.30634920634921)
# TimePoint(taxi_id=719, name='pick up', time=19.30634920634921)
# TimePoint(taxi_id=471, name='drop off', time=19.307936507936514)
# TimePoint(taxi_id=612, name='pick up', time=19.30952380952381)
# TimePoint(taxi_id=507, name='drop off', time=19.30952380952381)
# TimePoint(taxi_id=828, name='pick up', time=19.309523809523814)
# TimePoint(taxi_id=782, name='pick up', time=19.311111111111114)
# TimePoint(taxi_id=619, name='pick up', time=19.318253968253973)
# TimePoint(taxi_id=200, name='pick up', time=19.32142857142857)
# TimePoint(taxi_id=315, name='drop off', time=19.321428571428573)
# TimePoint(taxi_id=887, name='pick up', time=19.321428571428577)
# TimePoint(taxi_id=803, name='drop off', time=19.321428571428577)
# TimePoint(taxi_id=853, name='pick up', time=19.321428571428577)
# TimePoint(taxi_id=666, name='pick up', time=19.32142857142858)
# TimePoint(taxi_id=350, name='pick up', time=19.323015873015873)
# TimePoint(taxi_id=788, name='drop off', time=19.323015873015876)
# TimePoint(taxi_id=805, name='drop off', time=19.324603174603173)
# TimePoint(taxi_id=263, name='drop off', time=19.324603174603173)
# TimePoint(taxi_id=213, name='pick up', time=19.324603174603176)
# TimePoint(taxi_id=674, name='drop off', time=19.32460317460318)
# TimePoint(taxi_id=476, name='pick up', time=19.326190476190472)
# TimePoint(taxi_id=133, name='drop off', time=19.326190476190476)
# TimePoint(taxi_id=692, name='drop off', time=19.32619047619048)
# TimePoint(taxi_id=339, name='drop off', time=19.327777777777776)
# TimePoint(taxi_id=313, name='pick up', time=19.32777777777778)
# TimePoint(taxi_id=435, name='pick up', time=19.32777777777778)
# TimePoint(taxi_id=637, name='drop off', time=19.327777777777783)
# TimePoint(taxi_id=439, name='pick up', time=19.332539682539686)
# TimePoint(taxi_id=337, name='drop off', time=19.33650793650794)
# TimePoint(taxi_id=267, name='pick up', time=19.33809523809524)
# TimePoint(taxi_id=764, name='drop off', time=19.33809523809524)
# TimePoint(taxi_id=803, name='pick up', time=19.338095238095242)
# TimePoint(taxi_id=67, name='pick up', time=19.33809523809525)
# TimePoint(taxi_id=493, name='pick up', time=19.33968253968254)
# TimePoint(taxi_id=859, name='pick up', time=19.33968253968254)
# TimePoint(taxi_id=748, name='drop off', time=19.33968253968254)
# TimePoint(taxi_id=75, name='drop off', time=19.341269841269845)
# TimePoint(taxi_id=524, name='drop off', time=19.341269841269845)
# TimePoint(taxi_id=686, name='drop off', time=19.342857142857138)
# TimePoint(taxi_id=617, name='pick up', time=19.342857142857145)
# TimePoint(taxi_id=229, name='drop off', time=19.34444444444445)
# TimePoint(taxi_id=637, name='pick up', time=19.34444444444445)
# TimePoint(taxi_id=135, name='pick up', time=19.344444444444452)
# TimePoint(taxi_id=590, name='pick up', time=19.346031746031752)
# TimePoint(taxi_id=502, name='pick up', time=19.347619047619048)
# TimePoint(taxi_id=603, name='drop off', time=19.34920634920635)
# TimePoint(taxi_id=122, name='pick up', time=19.35079365079366)
# TimePoint(taxi_id=759, name='drop off', time=19.351587301587305)
# TimePoint(taxi_id=764, name='pick up', time=19.354761904761904)
# TimePoint(taxi_id=44, name='drop off', time=19.354761904761904)
# TimePoint(taxi_id=261, name='pick up', time=19.354761904761908)
# TimePoint(taxi_id=205, name='pick up', time=19.354761904761908)
# TimePoint(taxi_id=315, name='pick up', time=19.354761904761908)
# TimePoint(taxi_id=358, name='pick up', time=19.35476190476191)
# TimePoint(taxi_id=924, name='drop off', time=19.35476190476191)
# TimePoint(taxi_id=316, name='drop off', time=19.356349206349204)
# TimePoint(taxi_id=23, name='drop off', time=19.356349206349208)
# TimePoint(taxi_id=680, name='pick up', time=19.356349206349208)
# TimePoint(taxi_id=328, name='drop off', time=19.35634920634921)
# TimePoint(taxi_id=674, name='pick up', time=19.357936507936515)
# TimePoint(taxi_id=429, name='drop off', time=19.357936507936515)
# TimePoint(taxi_id=471, name='pick up', time=19.357936507936515)
# TimePoint(taxi_id=432, name='pick up', time=19.357936507936515)
# TimePoint(taxi_id=581, name='drop off', time=19.357936507936518)
# TimePoint(taxi_id=772, name='drop off', time=19.359523809523807)
# TimePoint(taxi_id=820, name='drop off', time=19.361111111111114)
# TimePoint(taxi_id=26, name='drop off', time=19.36269841269842)
# TimePoint(taxi_id=703, name='pick up', time=19.36825396825397)
# TimePoint(taxi_id=858, name='drop off', time=19.36984126984127)
# TimePoint(taxi_id=208, name='drop off', time=19.369841269841274)
# TimePoint(taxi_id=677, name='drop off', time=19.37142857142857)
# TimePoint(taxi_id=912, name='pick up', time=19.371428571428577)
# TimePoint(taxi_id=924, name='pick up', time=19.371428571428577)
# TimePoint(taxi_id=470, name='pick up', time=19.373015873015866)
# TimePoint(taxi_id=394, name='pick up', time=19.373015873015866)
# TimePoint(taxi_id=459, name='drop off', time=19.37301587301587)
# TimePoint(taxi_id=849, name='drop off', time=19.373015873015877)
# TimePoint(taxi_id=332, name='drop off', time=19.374603174603173)
# TimePoint(taxi_id=805, name='pick up', time=19.374603174603173)
# TimePoint(taxi_id=524, name='pick up', time=19.37460317460318)
# TimePoint(taxi_id=130, name='drop off', time=19.376190476190473)
# TimePoint(taxi_id=107, name='drop off', time=19.376190476190477)
# TimePoint(taxi_id=244, name='pick up', time=19.37777777777778)
# TimePoint(taxi_id=452, name='pick up', time=19.377777777777784)
# TimePoint(taxi_id=480, name='drop off', time=19.377777777777784)
# TimePoint(taxi_id=458, name='pick up', time=19.38095238095238)
# TimePoint(taxi_id=469, name='drop off', time=19.386507936507932)
# TimePoint(taxi_id=660, name='pick up', time=19.386507936507936)
# TimePoint(taxi_id=977, name='pick up', time=19.388095238095236)
# TimePoint(taxi_id=795, name='pick up', time=19.388095238095236)
# TimePoint(taxi_id=270, name='drop off', time=19.38809523809524)
# TimePoint(taxi_id=268, name='drop off', time=19.38968253968254)
# TimePoint(taxi_id=840, name='pick up', time=19.389682539682543)
# TimePoint(taxi_id=622, name='drop off', time=19.39126984126984)
# TimePoint(taxi_id=451, name='drop off', time=19.391269841269843)
# TimePoint(taxi_id=429, name='pick up', time=19.39126984126985)
# TimePoint(taxi_id=692, name='pick up', time=19.392857142857146)
# TimePoint(taxi_id=339, name='pick up', time=19.394444444444442)
# TimePoint(taxi_id=224, name='pick up', time=19.394444444444446)
# TimePoint(taxi_id=775, name='pick up', time=19.39603174603175)
# TimePoint(taxi_id=89, name='drop off', time=19.4031746031746)
# TimePoint(taxi_id=929, name='pick up', time=19.4031746031746)
# TimePoint(taxi_id=208, name='pick up', time=19.40317460317461)
# TimePoint(taxi_id=642, name='drop off', time=19.404761904761905)
# TimePoint(taxi_id=316, name='pick up', time=19.406349206349205)
# TimePoint(taxi_id=748, name='pick up', time=19.406349206349205)
# TimePoint(taxi_id=25, name='drop off', time=19.40634920634921)
# TimePoint(taxi_id=23, name='pick up', time=19.40634920634921)
# TimePoint(taxi_id=849, name='pick up', time=19.406349206349212)
# TimePoint(taxi_id=263, name='pick up', time=19.407936507936505)
# TimePoint(taxi_id=301, name='drop off', time=19.407936507936505)
# TimePoint(taxi_id=438, name='drop off', time=19.407936507936515)
# TimePoint(taxi_id=581, name='pick up', time=19.40793650793652)
# TimePoint(taxi_id=686, name='pick up', time=19.409523809523805)
# TimePoint(taxi_id=133, name='pick up', time=19.409523809523808)
# TimePoint(taxi_id=507, name='pick up', time=19.40952380952381)
# TimePoint(taxi_id=512, name='drop off', time=19.40952380952381)
# TimePoint(taxi_id=820, name='pick up', time=19.411111111111115)
# TimePoint(taxi_id=235, name='drop off', time=19.41825396825397)
# TimePoint(taxi_id=969, name='drop off', time=19.41984126984127)
# TimePoint(taxi_id=44, name='pick up', time=19.42142857142857)
# TimePoint(taxi_id=677, name='pick up', time=19.42142857142857)
# TimePoint(taxi_id=526, name='drop off', time=19.421428571428574)
# TimePoint(taxi_id=128, name='drop off', time=19.421428571428578)
# TimePoint(taxi_id=42, name='drop off', time=19.421428571428578)
# TimePoint(taxi_id=865, name='drop off', time=19.423015873015874)
# TimePoint(taxi_id=123, name='drop off', time=19.423015873015874)
# TimePoint(taxi_id=968, name='pick up', time=19.423015873015874)
# TimePoint(taxi_id=709, name='drop off', time=19.424603174603174)
# TimePoint(taxi_id=152, name='drop off', time=19.424603174603178)
# TimePoint(taxi_id=631, name='drop off', time=19.42460317460318)
# TimePoint(taxi_id=178, name='drop off', time=19.426190476190477)
# TimePoint(taxi_id=627, name='drop off', time=19.434920634920637)
# TimePoint(taxi_id=858, name='pick up', time=19.436507936507937)
# TimePoint(taxi_id=89, name='pick up', time=19.436507936507937)
# TimePoint(taxi_id=337, name='pick up', time=19.43650793650794)
# TimePoint(taxi_id=459, name='pick up', time=19.439682539682536)
# TimePoint(taxi_id=500, name='drop off', time=19.43968253968254)
# TimePoint(taxi_id=788, name='pick up', time=19.439682539682543)
# TimePoint(taxi_id=25, name='pick up', time=19.439682539682543)
# TimePoint(taxi_id=963, name='drop off', time=19.439682539682543)
# TimePoint(taxi_id=66, name='drop off', time=19.44126984126984)
# TimePoint(taxi_id=152, name='pick up', time=19.441269841269843)
# TimePoint(taxi_id=130, name='pick up', time=19.44285714285714)
# TimePoint(taxi_id=589, name='drop off', time=19.44285714285714)
# TimePoint(taxi_id=888, name='drop off', time=19.442857142857147)
# TimePoint(taxi_id=975, name='drop off', time=19.442857142857147)
# TimePoint(taxi_id=995, name='drop off', time=19.444444444444443)
# TimePoint(taxi_id=846, name='drop off', time=19.444444444444446)
# TimePoint(taxi_id=480, name='pick up', time=19.44444444444445)
# TimePoint(taxi_id=229, name='pick up', time=19.44444444444445)
# TimePoint(taxi_id=779, name='drop off', time=19.44920634920635)
# TimePoint(taxi_id=646, name='drop off', time=19.451587301587303)
# TimePoint(taxi_id=880, name='drop off', time=19.451587301587303)
# TimePoint(taxi_id=639, name='drop off', time=19.451587301587306)
# TimePoint(taxi_id=128, name='pick up', time=19.454761904761913)
# TimePoint(taxi_id=268, name='pick up', time=19.456349206349206)
# TimePoint(taxi_id=798, name='drop off', time=19.456349206349213)
# TimePoint(taxi_id=76, name='drop off', time=19.457936507936502)
# TimePoint(taxi_id=451, name='pick up', time=19.45793650793651)
# TimePoint(taxi_id=53, name='drop off', time=19.45952380952381)
# TimePoint(taxi_id=603, name='pick up', time=19.46587301587302)
# TimePoint(taxi_id=156, name='drop off', time=19.46825396825397)
# TimePoint(taxi_id=759, name='pick up', time=19.468253968253972)
# TimePoint(taxi_id=469, name='pick up', time=19.469841269841265)
# TimePoint(taxi_id=570, name='drop off', time=19.471428571428575)
# TimePoint(taxi_id=418, name='drop off', time=19.471428571428575)
# TimePoint(taxi_id=427, name='drop off', time=19.47142857142858)
# TimePoint(taxi_id=115, name='drop off', time=19.47301587301587)
# TimePoint(taxi_id=523, name='drop off', time=19.47301587301587)
# TimePoint(taxi_id=500, name='pick up', time=19.473015873015875)
# TimePoint(taxi_id=123, name='pick up', time=19.473015873015875)
# TimePoint(taxi_id=963, name='pick up', time=19.47301587301588)
# TimePoint(taxi_id=301, name='pick up', time=19.47460317460317)
# TimePoint(taxi_id=622, name='pick up', time=19.47460317460317)
# TimePoint(taxi_id=332, name='pick up', time=19.474603174603175)
# TimePoint(taxi_id=75, name='pick up', time=19.47460317460318)
# TimePoint(taxi_id=631, name='pick up', time=19.474603174603182)
# TimePoint(taxi_id=772, name='pick up', time=19.476190476190474)
# TimePoint(taxi_id=533, name='drop off', time=19.476190476190478)
# TimePoint(taxi_id=107, name='pick up', time=19.476190476190478)
# TimePoint(taxi_id=510, name='drop off', time=19.477777777777785)
# TimePoint(taxi_id=640, name='drop off', time=19.48253968253968)
# TimePoint(taxi_id=235, name='pick up', time=19.484920634920638)
# TimePoint(taxi_id=274, name='drop off', time=19.486507936507934)
# TimePoint(taxi_id=922, name='drop off', time=19.486507936507937)
# TimePoint(taxi_id=126, name='drop off', time=19.48650793650794)
# TimePoint(taxi_id=642, name='pick up', time=19.488095238095237)
# TimePoint(taxi_id=3, name='drop off', time=19.488095238095237)
# TimePoint(taxi_id=270, name='pick up', time=19.48809523809524)
# TimePoint(taxi_id=526, name='pick up', time=19.48809523809524)
# TimePoint(taxi_id=865, name='pick up', time=19.48968253968254)
# TimePoint(taxi_id=139, name='drop off', time=19.48968253968254)
# TimePoint(taxi_id=717, name='drop off', time=19.491269841269844)
# TimePoint(taxi_id=178, name='pick up', time=19.492857142857144)
# TimePoint(taxi_id=53, name='pick up', time=19.492857142857144)
# TimePoint(taxi_id=975, name='pick up', time=19.492857142857147)
# TimePoint(taxi_id=888, name='pick up', time=19.492857142857147)
# TimePoint(taxi_id=600, name='drop off', time=19.500000000000004)
# TimePoint(taxi_id=760, name='drop off', time=19.501587301587303)
# TimePoint(taxi_id=42, name='pick up', time=19.50476190476191)
# TimePoint(taxi_id=497, name='drop off', time=19.5063492063492)
# TimePoint(taxi_id=798, name='pick up', time=19.506349206349213)
# TimePoint(taxi_id=709, name='pick up', time=19.507936507936506)
# TimePoint(taxi_id=66, name='pick up', time=19.507936507936506)
# TimePoint(taxi_id=871, name='drop off', time=19.50793650793651)
# TimePoint(taxi_id=373, name='drop off', time=19.50952380952381)
# TimePoint(taxi_id=807, name='drop off', time=19.512698412698416)
# TimePoint(taxi_id=918, name='drop off', time=19.51269841269842)
# TimePoint(taxi_id=779, name='pick up', time=19.515873015873016)
# TimePoint(taxi_id=153, name='drop off', time=19.517460317460316)
# TimePoint(taxi_id=639, name='pick up', time=19.518253968253973)
# TimePoint(taxi_id=326, name='drop off', time=19.518253968253973)
# TimePoint(taxi_id=43, name='drop off', time=19.518253968253973)
# TimePoint(taxi_id=329, name='drop off', time=19.51984126984127)
# TimePoint(taxi_id=460, name='drop off', time=19.51984126984127)
# TimePoint(taxi_id=169, name='drop off', time=19.519841269841276)
# TimePoint(taxi_id=899, name='drop off', time=19.52142857142857)
# TimePoint(taxi_id=875, name='drop off', time=19.52142857142857)
# TimePoint(taxi_id=177, name='drop off', time=19.521428571428572)
# TimePoint(taxi_id=896, name='drop off', time=19.521428571428576)
# TimePoint(taxi_id=328, name='pick up', time=19.52301587301588)
# TimePoint(taxi_id=303, name='drop off', time=19.52301587301588)
# TimePoint(taxi_id=944, name='drop off', time=19.52301587301588)
# TimePoint(taxi_id=512, name='pick up', time=19.52619047619048)
# TimePoint(taxi_id=533, name='pick up', time=19.52619047619048)
# TimePoint(taxi_id=568, name='drop off', time=19.52619047619048)
# TimePoint(taxi_id=183, name='drop off', time=19.52619047619048)
# TimePoint(taxi_id=995, name='pick up', time=19.527777777777775)
# TimePoint(taxi_id=26, name='pick up', time=19.52936507936509)
# TimePoint(taxi_id=43, name='pick up', time=19.53492063492064)
# TimePoint(taxi_id=126, name='pick up', time=19.53650793650794)
# TimePoint(taxi_id=418, name='pick up', time=19.53809523809524)
# TimePoint(taxi_id=957, name='drop off', time=19.53809523809524)
# TimePoint(taxi_id=427, name='pick up', time=19.538095238095245)
# TimePoint(taxi_id=916, name='drop off', time=19.539682539682538)
# TimePoint(taxi_id=423, name='drop off', time=19.539682539682538)
# TimePoint(taxi_id=802, name='pick up', time=19.539682539682545)
# TimePoint(taxi_id=802, name='drop off', time=19.539682539682545)
# TimePoint(taxi_id=76, name='pick up', time=19.541269841269834)
# TimePoint(taxi_id=398, name='drop off', time=19.541269841269845)
# TimePoint(taxi_id=438, name='pick up', time=19.54126984126985)
# TimePoint(taxi_id=710, name='drop off', time=19.542857142857137)
# TimePoint(taxi_id=878, name='drop off', time=19.542857142857144)
# TimePoint(taxi_id=577, name='drop off', time=19.542857142857148)
# TimePoint(taxi_id=219, name='drop off', time=19.54444444444444)
# TimePoint(taxi_id=846, name='pick up', time=19.544444444444448)
# TimePoint(taxi_id=510, name='pick up', time=19.54444444444445)
# TimePoint(taxi_id=322, name='drop off', time=19.546031746031755)
# TimePoint(taxi_id=156, name='pick up', time=19.5515873015873)
# TimePoint(taxi_id=627, name='pick up', time=19.551587301587304)
# TimePoint(taxi_id=607, name='drop off', time=19.553174603174604)
# TimePoint(taxi_id=969, name='pick up', time=19.553174603174604)
# TimePoint(taxi_id=875, name='pick up', time=19.554761904761904)
# TimePoint(taxi_id=916, name='pick up', time=19.556349206349203)
# TimePoint(taxi_id=523, name='pick up', time=19.556349206349203)
# TimePoint(taxi_id=139, name='pick up', time=19.556349206349207)
# TimePoint(taxi_id=717, name='pick up', time=19.55793650793651)
# TimePoint(taxi_id=815, name='drop off', time=19.55793650793651)
# TimePoint(taxi_id=618, name='drop off', time=19.559523809523807)
# TimePoint(taxi_id=321, name='drop off', time=19.55952380952381)
# TimePoint(taxi_id=654, name='drop off', time=19.559523809523814)
# TimePoint(taxi_id=275, name='drop off', time=19.559523809523814)
# TimePoint(taxi_id=354, name='drop off', time=19.56111111111111)
# TimePoint(taxi_id=396, name='drop off', time=19.56111111111111)
# TimePoint(taxi_id=807, name='pick up', time=19.562698412698417)
# TimePoint(taxi_id=760, name='pick up', time=19.56825396825397)
# TimePoint(taxi_id=646, name='pick up', time=19.56825396825397)
# TimePoint(taxi_id=300, name='drop off', time=19.569841269841266)
# TimePoint(taxi_id=922, name='pick up', time=19.56984126984127)
# TimePoint(taxi_id=177, name='pick up', time=19.571428571428573)
# TimePoint(taxi_id=112, name='drop off', time=19.571428571428573)
# TimePoint(taxi_id=656, name='drop off', time=19.571428571428577)
# TimePoint(taxi_id=825, name='drop off', time=19.571428571428577)
# TimePoint(taxi_id=109, name='drop off', time=19.57142857142858)
# TimePoint(taxi_id=497, name='pick up', time=19.573015873015866)
# TimePoint(taxi_id=529, name='drop off', time=19.573015873015873)
# TimePoint(taxi_id=516, name='drop off', time=19.573015873015873)
# TimePoint(taxi_id=115, name='pick up', time=19.573015873015873)
# TimePoint(taxi_id=808, name='drop off', time=19.573015873015876)
# TimePoint(taxi_id=754, name='drop off', time=19.573015873015876)
# TimePoint(taxi_id=303, name='pick up', time=19.57301587301588)
# TimePoint(taxi_id=944, name='pick up', time=19.57301587301588)
# TimePoint(taxi_id=871, name='pick up', time=19.574603174603176)
# TimePoint(taxi_id=287, name='drop off', time=19.574603174603176)
# TimePoint(taxi_id=40, name='drop off', time=19.57460317460318)
# TimePoint(taxi_id=354, name='pick up', time=19.577777777777776)
# TimePoint(taxi_id=640, name='pick up', time=19.582539682539682)
# TimePoint(taxi_id=153, name='pick up', time=19.584126984126982)
# TimePoint(taxi_id=326, name='pick up', time=19.58492063492064)
# TimePoint(taxi_id=300, name='pick up', time=19.58650793650793)
# TimePoint(taxi_id=563, name='drop off', time=19.586507936507935)
# TimePoint(taxi_id=132, name='drop off', time=19.588095238095235)
# TimePoint(taxi_id=899, name='pick up', time=19.588095238095235)
# TimePoint(taxi_id=3, name='pick up', time=19.58809523809524)
# TimePoint(taxi_id=656, name='pick up', time=19.588095238095242)
# TimePoint(taxi_id=688, name='drop off', time=19.58809523809525)
# TimePoint(taxi_id=220, name='drop off', time=19.58968253968253)
# TimePoint(taxi_id=475, name='drop off', time=19.589682539682535)
# TimePoint(taxi_id=947, name='drop off', time=19.589682539682542)
# TimePoint(taxi_id=685, name='drop off', time=19.59126984126984)
# TimePoint(taxi_id=960, name='drop off', time=19.59126984126984)
# TimePoint(taxi_id=15, name='drop off', time=19.591269841269842)
# TimePoint(taxi_id=398, name='pick up', time=19.591269841269845)
# TimePoint(taxi_id=815, name='pick up', time=19.591269841269845)
# TimePoint(taxi_id=336, name='drop off', time=19.591269841269852)
# TimePoint(taxi_id=403, name='drop off', time=19.592857142857145)
# TimePoint(taxi_id=321, name='pick up', time=19.592857142857145)
# TimePoint(taxi_id=183, name='pick up', time=19.592857142857145)
# TimePoint(taxi_id=577, name='pick up', time=19.59285714285715)
# TimePoint(taxi_id=272, name='drop off', time=19.594444444444452)
# TimePoint(taxi_id=694, name='drop off', time=19.59603174603175)
# TimePoint(taxi_id=918, name='pick up', time=19.596031746031752)
# TimePoint(taxi_id=406, name='drop off', time=19.60079365079366)
# TimePoint(taxi_id=880, name='pick up', time=19.6015873015873)
# TimePoint(taxi_id=992, name='drop off', time=19.60158730158731)
# TimePoint(taxi_id=274, name='pick up', time=19.6031746031746)
# TimePoint(taxi_id=570, name='pick up', time=19.604761904761908)
# TimePoint(taxi_id=408, name='drop off', time=19.604761904761908)
# TimePoint(taxi_id=710, name='pick up', time=19.609523809523804)
# TimePoint(taxi_id=589, name='pick up', time=19.609523809523807)
# TimePoint(taxi_id=878, name='pick up', time=19.60952380952381)
# TimePoint(taxi_id=373, name='pick up', time=19.60952380952381)
# TimePoint(taxi_id=654, name='pick up', time=19.609523809523814)
# TimePoint(taxi_id=782, name='drop off', time=19.611111111111114)
# TimePoint(taxi_id=520, name='drop off', time=19.614285714285714)
# TimePoint(taxi_id=600, name='pick up', time=19.61666666666667)
# TimePoint(taxi_id=893, name='drop off', time=19.619841269841263)
# TimePoint(taxi_id=345, name='drop off', time=19.619841269841274)
# TimePoint(taxi_id=169, name='pick up', time=19.619841269841277)
# TimePoint(taxi_id=109, name='pick up', time=19.62142857142858)
# TimePoint(taxi_id=168, name='drop off', time=19.62301587301587)
# TimePoint(taxi_id=61, name='drop off', time=19.62301587301587)
# TimePoint(taxi_id=513, name='drop off', time=19.623015873015877)
# TimePoint(taxi_id=805, name='drop off', time=19.624603174603173)
# TimePoint(taxi_id=309, name='drop off', time=19.624603174603177)
# TimePoint(taxi_id=630, name='drop off', time=19.624603174603177)
# TimePoint(taxi_id=910, name='drop off', time=19.62460317460318)
# TimePoint(taxi_id=98, name='drop off', time=19.62460317460318)
# TimePoint(taxi_id=623, name='drop off', time=19.624603174603184)
# TimePoint(taxi_id=403, name='pick up', time=19.62619047619048)
# TimePoint(taxi_id=219, name='pick up', time=19.627777777777773)
# TimePoint(taxi_id=782, name='pick up', time=19.62777777777778)
# TimePoint(taxi_id=458, name='drop off', time=19.63095238095238)
# TimePoint(taxi_id=992, name='pick up', time=19.634920634920643)
# ...
# TimePoint(taxi_id=754, name='drop off', time=23.55634920634921)
# TimePoint(taxi_id=622, name='drop off', time=23.557936507936503)
# TimePoint(taxi_id=76, name='end shift ', time=23.557936507936507)
# TimePoint(taxi_id=519, name='pick up', time=23.557936507936507)
# TimePoint(taxi_id=524, name='drop off', time=23.557936507936518)
# TimePoint(taxi_id=476, name='drop off', time=23.559523809523807)
# TimePoint(taxi_id=452, name='end shift ', time=23.56111111111112)
# TimePoint(taxi_id=520, name='pick up', time=23.564285714285717)
# TimePoint(taxi_id=329, name='drop off', time=23.569841269841266)
# TimePoint(taxi_id=3, name='end shift ', time=23.571428571428573)
# TimePoint(taxi_id=764, name='drop off', time=23.571428571428573)
# TimePoint(taxi_id=109, name='drop off', time=23.571428571428577)
# TimePoint(taxi_id=895, name='pick up', time=23.571428571428587)
# TimePoint(taxi_id=654, name='drop off', time=23.576190476190483)
# TimePoint(taxi_id=272, name='pick up', time=23.57777777777779)
# TimePoint(taxi_id=619, name='drop off', time=23.584920634920632)
# TimePoint(taxi_id=89, name='end shift ', time=23.586507936507946)
# TimePoint(taxi_id=67, name='pick up', time=23.588095238095253)
# TimePoint(taxi_id=147, name='drop off', time=23.589682539682542)
# TimePoint(taxi_id=963, name='drop off', time=23.589682539682546)
# TimePoint(taxi_id=805, name='drop off', time=23.591269841269842)
# TimePoint(taxi_id=451, name='pick up', time=23.591269841269845)
# TimePoint(taxi_id=621, name='pick up', time=23.59126984126985)
# TimePoint(taxi_id=871, name='pick up', time=23.59126984126985)
# TimePoint(taxi_id=686, name='pick up', time=23.592857142857145)
# TimePoint(taxi_id=512, name='drop off', time=23.592857142857145)
# TimePoint(taxi_id=692, name='drop off', time=23.59285714285715)
# TimePoint(taxi_id=107, name='pick up', time=23.592857142857152)
# TimePoint(taxi_id=224, name='pick up', time=23.59444444444445)
# TimePoint(taxi_id=637, name='pick up', time=23.594444444444452)
# TimePoint(taxi_id=458, name='pick up', time=23.597619047619048)
# TimePoint(taxi_id=655, name='end shift ', time=23.601587301587305)
# TimePoint(taxi_id=956, name='drop off', time=23.601587301587315)
# TimePoint(taxi_id=333, name='end shift ', time=23.603174603174605)
# TimePoint(taxi_id=345, name='pick up', time=23.603174603174605)
# TimePoint(taxi_id=28, name='drop off', time=23.603174603174608)
# TimePoint(taxi_id=677, name='drop off', time=23.604761904761904)
# TimePoint(taxi_id=597, name='pick up', time=23.606349206349204)
# TimePoint(taxi_id=523, name='drop off', time=23.606349206349204)
# TimePoint(taxi_id=960, name='drop off', time=23.60793650793651)
# TimePoint(taxi_id=623, name='drop off', time=23.60793650793651)
# TimePoint(taxi_id=524, name='pick up', time=23.607936507936518)
# TimePoint(taxi_id=476, name='pick up', time=23.609523809523807)
# TimePoint(taxi_id=710, name='drop off', time=23.609523809523807)
# TimePoint(taxi_id=626, name='drop off', time=23.609523809523825)
# TimePoint(taxi_id=846, name='drop off', time=23.611111111111114)
# TimePoint(taxi_id=229, name='end shift ', time=23.61111111111112)
# TimePoint(taxi_id=652, name='pick up', time=23.621428571428574)
# TimePoint(taxi_id=924, name='end shift ', time=23.62142857142858)
# TimePoint(taxi_id=754, name='end shift ', time=23.623015873015877)
# TimePoint(taxi_id=931, name='drop off', time=23.62301587301588)
# TimePoint(taxi_id=840, name='pick up', time=23.623015873015884)
# TimePoint(taxi_id=152, name='drop off', time=23.624603174603173)
# TimePoint(taxi_id=812, name='pick up', time=23.624603174603184)
# TimePoint(taxi_id=734, name='end shift ', time=23.630952380952387)
# TimePoint(taxi_id=554, name='end shift ', time=23.634920634920633)
# TimePoint(taxi_id=646, name='drop off', time=23.63492063492064)
# TimePoint(taxi_id=893, name='drop off', time=23.636507936507925)
# TimePoint(taxi_id=28, name='pick up', time=23.636507936507943)
# TimePoint(taxi_id=168, name='drop off', time=23.63968253968254)
# TimePoint(taxi_id=717, name='drop off', time=23.64126984126985)
# TimePoint(taxi_id=21, name='drop off', time=23.64126984126985)
# TimePoint(taxi_id=373, name='drop off', time=23.64285714285714)
# TimePoint(taxi_id=878, name='end shift ', time=23.642857142857146)
# TimePoint(taxi_id=654, name='pick up', time=23.64285714285715)
# TimePoint(taxi_id=122, name='drop off', time=23.650793650793663)
# TimePoint(taxi_id=899, name='drop off', time=23.654761904761905)
# TimePoint(taxi_id=109, name='pick up', time=23.65476190476191)
# TimePoint(taxi_id=132, name='end shift ', time=23.65476190476191)
# TimePoint(taxi_id=128, name='drop off', time=23.654761904761916)
# TimePoint(taxi_id=968, name='drop off', time=23.656349206349216)
# TimePoint(taxi_id=622, name='pick up', time=23.657936507936505)
# TimePoint(taxi_id=805, name='pick up', time=23.65793650793651)
# TimePoint(taxi_id=631, name='end shift ', time=23.65793650793652)
# TimePoint(taxi_id=581, name='drop off', time=23.657936507936526)
# TimePoint(taxi_id=710, name='pick up', time=23.659523809523808)
# TimePoint(taxi_id=575, name='drop off', time=23.659523809523808)
# TimePoint(taxi_id=846, name='pick up', time=23.661111111111115)
# TimePoint(taxi_id=153, name='end shift ', time=23.66746031746032)
# TimePoint(taxi_id=886, name='drop off', time=23.668253968253964)
# TimePoint(taxi_id=856, name='drop off', time=23.67142857142857)
# TimePoint(taxi_id=408, name='drop off', time=23.67142857142857)
# TimePoint(taxi_id=21, name='pick up', time=23.674603174603185)
# TimePoint(taxi_id=512, name='pick up', time=23.676190476190477)
# TimePoint(taxi_id=692, name='pick up', time=23.67619047619048)
# TimePoint(taxi_id=160, name='drop off', time=23.67777777777778)
# TimePoint(taxi_id=694, name='drop off', time=23.679365079365084)
# TimePoint(taxi_id=956, name='pick up', time=23.684920634920648)
# TimePoint(taxi_id=764, name='end shift ', time=23.68809523809524)
# TimePoint(taxi_id=899, name='pick up', time=23.68809523809524)
# TimePoint(taxi_id=152, name='pick up', time=23.69126984126984)
# TimePoint(taxi_id=623, name='pick up', time=23.691269841269843)
# TimePoint(taxi_id=75, name='drop off', time=23.691269841269843)
# TimePoint(taxi_id=815, name='end shift ', time=23.691269841269843)
# TimePoint(taxi_id=511, name='drop off', time=23.691269841269847)
# TimePoint(taxi_id=626, name='pick up', time=23.692857142857157)
# TimePoint(taxi_id=435, name='drop off', time=23.69444444444444)
# TimePoint(taxi_id=995, name='drop off', time=23.694444444444443)
# TimePoint(taxi_id=122, name='pick up', time=23.700793650793663)
# TimePoint(taxi_id=886, name='pick up', time=23.7015873015873)
# TimePoint(taxi_id=660, name='drop off', time=23.703174603174606)
# TimePoint(taxi_id=680, name='end shift ', time=23.70634920634921)
# TimePoint(taxi_id=968, name='pick up', time=23.706349206349216)
# TimePoint(taxi_id=960, name='pick up', time=23.707936507936513)
# TimePoint(taxi_id=717, name='pick up', time=23.707936507936516)
# TimePoint(taxi_id=373, name='pick up', time=23.709523809523805)
# TimePoint(taxi_id=160, name='pick up', time=23.711111111111116)
# TimePoint(taxi_id=633, name='drop off', time=23.716666666666658)
# TimePoint(taxi_id=893, name='pick up', time=23.719841269841258)
# TimePoint(taxi_id=177, name='drop off', time=23.721428571428568)
# TimePoint(taxi_id=677, name='end shift ', time=23.72142857142857)
# TimePoint(taxi_id=666, name='drop off', time=23.721428571428575)
# TimePoint(taxi_id=656, name='drop off', time=23.721428571428582)
# TimePoint(taxi_id=115, name='drop off', time=23.723015873015868)
# TimePoint(taxi_id=168, name='pick up', time=23.72301587301587)
# TimePoint(taxi_id=963, name='end shift ', time=23.72301587301588)
# TimePoint(taxi_id=931, name='pick up', time=23.723015873015882)
# TimePoint(taxi_id=432, name='drop off', time=23.724603174603182)
# TimePoint(taxi_id=575, name='pick up', time=23.726190476190474)
# TimePoint(taxi_id=617, name='drop off', time=23.72619047619048)
# TimePoint(taxi_id=590, name='drop off', time=23.72936507936509)
# TimePoint(taxi_id=619, name='end shift ', time=23.734920634920634)
# TimePoint(taxi_id=646, name='end shift ', time=23.73492063492064)
# TimePoint(taxi_id=177, name='pick up', time=23.738095238095234)
# TimePoint(taxi_id=523, name='pick up', time=23.739682539682537)
# TimePoint(taxi_id=194, name='drop off', time=23.74285714285714)
# TimePoint(taxi_id=995, name='pick up', time=23.744444444444444)
# TimePoint(taxi_id=329, name='end shift ', time=23.7531746031746)
# TimePoint(taxi_id=358, name='drop off', time=23.754761904761917)
# TimePoint(taxi_id=350, name='drop off', time=23.756349206349206)
# TimePoint(taxi_id=513, name='drop off', time=23.756349206349217)
# TimePoint(taxi_id=75, name='pick up', time=23.75793650793651)
# TimePoint(taxi_id=183, name='drop off', time=23.75952380952381)
# TimePoint(taxi_id=590, name='pick up', time=23.762698412698423)
# TimePoint(taxi_id=660, name='pick up', time=23.769841269841272)
# TimePoint(taxi_id=408, name='pick up', time=23.771428571428572)
# TimePoint(taxi_id=128, name='pick up', time=23.771428571428583)
# TimePoint(taxi_id=115, name='pick up', time=23.77301587301587)
# TimePoint(taxi_id=429, name='drop off', time=23.774603174603186)
# TimePoint(taxi_id=612, name='drop off', time=23.776190476190475)
# TimePoint(taxi_id=178, name='drop off', time=23.776190476190482)
# TimePoint(taxi_id=775, name='drop off', time=23.779365079365082)
# TimePoint(taxi_id=694, name='pick up', time=23.779365079365085)
# TimePoint(taxi_id=200, name='drop off', time=23.788095238095245)
# TimePoint(taxi_id=656, name='end shift ', time=23.78809523809525)
# TimePoint(taxi_id=358, name='pick up', time=23.788095238095252)
# TimePoint(taxi_id=513, name='pick up', time=23.789682539682552)
# TimePoint(taxi_id=511, name='pick up', time=23.79126984126985)
# TimePoint(taxi_id=581, name='end shift ', time=23.79126984126986)
# TimePoint(taxi_id=617, name='pick up', time=23.792857142857148)
# TimePoint(taxi_id=435, name='pick up', time=23.79444444444444)
# TimePoint(taxi_id=480, name='drop off', time=23.794444444444448)
# TimePoint(taxi_id=502, name='drop off', time=23.797619047619055)
# TimePoint(taxi_id=703, name='drop off', time=23.818253968253966)
# TimePoint(taxi_id=666, name='pick up', time=23.821428571428577)
# TimePoint(taxi_id=212, name='drop off', time=23.821428571428584)
# TimePoint(taxi_id=556, name='drop off', time=23.821428571428584)
# TimePoint(taxi_id=147, name='end shift ', time=23.823015873015876)
# TimePoint(taxi_id=428, name='drop off', time=23.824603174603173)
# TimePoint(taxi_id=263, name='drop off', time=23.824603174603173)
# TimePoint(taxi_id=15, name='drop off', time=23.82460317460318)
# TimePoint(taxi_id=432, name='end shift ', time=23.824603174603183)
# TimePoint(taxi_id=39, name='drop off', time=23.826190476190476)
# TimePoint(taxi_id=183, name='pick up', time=23.826190476190476)
# TimePoint(taxi_id=73, name='drop off', time=23.827777777777786)
# TimePoint(taxi_id=445, name='drop off', time=23.830952380952386)
# TimePoint(taxi_id=639, name='drop off', time=23.834920634920643)
# TimePoint(taxi_id=856, name='end shift ', time=23.838095238095235)
# TimePoint(taxi_id=42, name='drop off', time=23.838095238095246)
# TimePoint(taxi_id=859, name='drop off', time=23.839682539682546)
# TimePoint(taxi_id=480, name='pick up', time=23.84444444444445)
# TimePoint(taxi_id=26, name='drop off', time=23.846031746031763)
# TimePoint(taxi_id=640, name='drop off', time=23.849206349206348)
# TimePoint(taxi_id=875, name='drop off', time=23.854761904761908)
# TimePoint(taxi_id=40, name='drop off', time=23.85793650793651)
# TimePoint(taxi_id=194, name='end shift ', time=23.859523809523807)
# TimePoint(taxi_id=468, name='drop off', time=23.859523809523814)
# TimePoint(taxi_id=178, name='end shift ', time=23.859523809523814)
# TimePoint(taxi_id=155, name='drop off', time=23.861111111111118)
# TimePoint(taxi_id=445, name='end shift ', time=23.864285714285717)
# TimePoint(taxi_id=67, name='drop off', time=23.871428571428588)
# TimePoint(taxi_id=350, name='pick up', time=23.873015873015873)
# TimePoint(taxi_id=947, name='drop off', time=23.873015873015884)
# TimePoint(taxi_id=287, name='drop off', time=23.87460317460317)
# TimePoint(taxi_id=428, name='pick up', time=23.874603174603173)
# TimePoint(taxi_id=336, name='drop off', time=23.874603174603187)
# TimePoint(taxi_id=532, name='drop off', time=23.882539682539687)
# TimePoint(taxi_id=703, name='end shift ', time=23.884920634920636)
# TimePoint(taxi_id=300, name='drop off', time=23.88650793650793)
# TimePoint(taxi_id=808, name='drop off', time=23.889682539682543)
# TimePoint(taxi_id=263, name='pick up', time=23.89126984126984)
# TimePoint(taxi_id=321, name='drop off', time=23.892857142857142)
# TimePoint(taxi_id=637, name='drop off', time=23.894444444444453)
# TimePoint(taxi_id=775, name='pick up', time=23.89603174603175)
# TimePoint(taxi_id=502, name='end shift ', time=23.897619047619056)
# TimePoint(taxi_id=633, name='end shift ', time=23.89999999999999)
# TimePoint(taxi_id=30, name='drop off', time=23.9031746031746)
# TimePoint(taxi_id=208, name='drop off', time=23.90317460317461)
# TimePoint(taxi_id=859, name='pick up', time=23.906349206349212)
# TimePoint(taxi_id=39, name='pick up', time=23.909523809523808)
# TimePoint(taxi_id=73, name='pick up', time=23.91111111111112)
# TimePoint(taxi_id=520, name='drop off', time=23.914285714285718)
# TimePoint(taxi_id=42, name='pick up', time=23.921428571428578)
# TimePoint(taxi_id=427, name='drop off', time=23.921428571428578)
# TimePoint(taxi_id=61, name='drop off', time=23.92301587301587)
# TimePoint(taxi_id=808, name='pick up', time=23.923015873015878)
# TimePoint(taxi_id=840, name='drop off', time=23.923015873015885)
# TimePoint(taxi_id=40, name='pick up', time=23.924603174603178)
# TimePoint(taxi_id=15, name='end shift ', time=23.92460317460318)
# TimePoint(taxi_id=468, name='pick up', time=23.92619047619048)
# TimePoint(taxi_id=640, name='pick up', time=23.93253968253968)
# TimePoint(taxi_id=639, name='pick up', time=23.934920634920644)
# TimePoint(taxi_id=208, name='pick up', time=23.936507936507944)
# TimePoint(taxi_id=434, name='drop off', time=23.938095238095247)
# TimePoint(taxi_id=556, name='pick up', time=23.93809523809525)
# TimePoint(taxi_id=67, name='pick up', time=23.938095238095254)
# TimePoint(taxi_id=947, name='pick up', time=23.93968253968255)
# TimePoint(taxi_id=621, name='drop off', time=23.94126984126985)
# TimePoint(taxi_id=793, name='drop off', time=23.94126984126985)
# TimePoint(taxi_id=918, name='drop off', time=23.94603174603175)
# TimePoint(taxi_id=26, name='end shift ', time=23.946031746031764)
# TimePoint(taxi_id=731, name='drop off', time=23.954761904761906)
# TimePoint(taxi_id=200, name='end shift ', time=23.95476190476191)
# TimePoint(taxi_id=212, name='end shift ', time=23.95476190476192)
# TimePoint(taxi_id=287, name='pick up', time=23.957936507936502)
# TimePoint(taxi_id=336, name='end shift ', time=23.95793650793652)
# TimePoint(taxi_id=686, name='drop off', time=23.959523809523812)
# TimePoint(taxi_id=975, name='drop off', time=23.95952380952382)
# TimePoint(taxi_id=637, name='pick up', time=23.96111111111112)
# TimePoint(taxi_id=520, name='pick up', time=23.96428571428572)
# TimePoint(taxi_id=269, name='drop off', time=23.969841269841268)
# TimePoint(taxi_id=875, name='end shift ', time=23.971428571428575)
# TimePoint(taxi_id=497, name='drop off', time=23.97301587301587)
# TimePoint(taxi_id=519, name='drop off', time=23.974603174603175)
# TimePoint(taxi_id=812, name='drop off', time=23.974603174603185)
# TimePoint(taxi_id=321, name='pick up', time=23.976190476190474)
# TimePoint(taxi_id=589, name='drop off', time=23.976190476190478)
# TimePoint(taxi_id=272, name='drop off', time=23.97777777777779)
# TimePoint(taxi_id=532, name='pick up', time=23.982539682539688)
# TimePoint(taxi_id=269, name='pick up', time=23.986507936507934)
# TimePoint(taxi_id=825, name='drop off', time=23.988095238095237)
# TimePoint(taxi_id=652, name='drop off', time=23.98809523809524)
# TimePoint(taxi_id=61, name='pick up', time=23.989682539682537)
# TimePoint(taxi_id=840, name='pick up', time=23.98968253968255)
# TimePoint(taxi_id=793, name='pick up', time=23.99126984126985)
# TimePoint(taxi_id=612, name='end shift ', time=23.992857142857144)
# TimePoint(taxi_id=654, name='drop off', time=23.99285714285715)
# TimePoint(taxi_id=895, name='drop off', time=24.00476190476192)

# %% [markdown]
# Выше показан результат моделирования (в вашем случае он будет другим, так как мы не установили начальное значение — при каждом перезапуске кода оно выбирается случайным образом).

# %% [markdown]
# **Начальное значение генератора случайных чисел**<br>
# Создавая код, отвечающий за генерирование случайных чисел, вам может понадобиться сделать его полностью воспроизводимым (например, планируя проводить модульное тестирование, которое обычно выполняется со случайными настройками, или отладку кода со суженным диапазоном изменяемых параметров). Чтобы обеспечить генерирование случайных чисел в одном и том же (неслучайном) порядке, следует определить начальное значение процесса. Это общепринятая настройка — возможность установки начального значения представлена в большинстве языков программирования.<br>
# Для простоты отображения мы округлили временные точки до ближайшей минуты, хотя могли остановиться на более точных значениях. Используемое временное разрешение зависит от преследуемых целей.<br>
# • Если нужно учитывать влияние машин такси на общегородской трафик, то лучше остановиться на почасовых временных точках.<br>
# • Создавая мобильное приложение вызова такси, нужно исходить из соображений вычислительной нагрузки на сервер. Скорее всего, придется довольствоваться минутной или более высокой разрешающей способностью, чтобы не перегружать сетевую и вычислительную инфраструктуру.<br>
# Ранее нами было принято решение регистрировать объекты класса TimePoints каждого такси в момент их “возникновения”. Иначе говоря, мы сообщаем о начале поездки в такси (посадка пассажира), не указывая момента ее окончания, хотя в его определении нет ничего сложного. Это один из способов сделать временной ряд более реалистичным в том понимании, что регистрация событий в нем ведется в режиме реального времени.<br>
# Обратите внимание, что, как и в предыдущем случае, моделирование все еще не приводит к получению временных рядов. Но в нашем распоряжении находится журнал событий, который может послужить основой для временного ряда. Существует сразу несколько возможностей.<br>
# • Запись результатов моделирования в файл CSV или базу данных временныхрядов.<br>
# • Подключение к нашей модели одной из онлайн-моделей, обеспечивающих разработку конвейера потоковой обработки данных в режиме реального времени.<br>
# • Сохранение выходных данных в файл или базу данных с последующей обработкой (с риском получения упреждения) для представления в более удобном формате, например, совмещение точек начала и окончания поездок, чтобы получить представление об их длительности в разное время суток.<br>
# Наряду с проверкой гипотезы о динамичности системы управления таксопарком моделирование таких данных позволяет ответить на некоторые другие вопросы. В частности, синтезированные временные ряды могут пригодиться в следующих ситуациях.<br>
# • Тестирование метрик различных моделей прогнозирования по известной динамической модели<br>
# • Построение конвейера реальных данных, который в их отсутствие (ожидание) отлаживается на синтезированных данных.
# Используя генераторы и другие преимущества объектно-ориентированного программирования, вы получаете в свое распоряжение более совершенные инструменты анализа временных рядов. Рассмотренный ваше пример показывает, что генераторы позволяют упростить исходную модель, а также заметно улучшить программный код.<br>
# **Преимущества моделирования, основанного на использовании агентов**<br>
# Продемонстрированное решение оказалось верным, но в нем проводится слишком много проверок данных на соответствие логическим правилам, принятым в системе. Если целью моделирования дискретных событий, основанных на действиях дискретных акторов, является получение источников данных для временных рядов, то рассмотрите возможность его выполнения с помощью специальных модулей, в первую очередь — с помощью модуля SimPy (https://simpy.reacithedocs.io/en/latest), снабженного удобным программным интерфейсом и обладающего достаточной гибкостью для моделирования процессов, описанных в этом разделе.<br>

# %% [markdown]
# <h2>Моделирование физических процессов</h2>

# %% [markdown]
# В еще одном сценарии моделирования поведение системы определяется физическими законами, управляемыми по собственному усмотрению. Это не обязательно должны быть физические системы, — рассмотренные далее принципы справедливы для систем многих других типов.<br>
#
# • Специалисты, занимающиеся количественным финансовым анализом, утверждают, что поведение рынков прекрасно описывается “физическими” законами. Это же утверждение справедливо для экономических систем, хотя и в несколько иных временных масштабах.<br>
#
# • Психологи настаивают на том, что общесоциальные принципы принятия решений основаны на “психофизических” принципах, которые могут послужить основой для “физических” правил модели, описывающей ожидаемую человеческую реакцию на различные поведенческие ситуации, изменяющиеся во времени.<br>
#
# • Биологи отслеживают временные изменения во многих экосистемах, подверженных самым разным воздействиям.<br>
#
# Рассмотрим простой пример моделирования физической системы, заключающийся в изучении поведения магнитного материала. Для описания такой системы воспользуемся моделью, которая в статистической физике известна как модель Изинга (Модель Изинга является хорошо изученной математической моделью статистической физики, описывающей поведение магнитных материалов. В Интернете можно найти продолжение ее описания и огромное количество примеров кода ее реализации в прикладных задачах.). Сразу заметим, что будем изучать поведение упрощенной модели Изинга. В ней предполагается, что в исходном состоянии отдельные компоненты магнитного материала имеют случайную направленность. Нам нужно инициализировать такую систему и посмотреть, как она будет эволюционировать к состоянию, в котором все магнитные компоненты выстраиваются в одном направлении под действием известных физических законов, устанавливаемых всего несколькими строками кода.<br>
# Мы также изучим принципы моделирования таких систем по методу Монте-Карло с использованием марковских цепей (МСМС — Markov Chain Monte Carlo), обсудим особенности метода и тонкости его применения в рамках модели Изинга.<br>
#
# *Моделирование по методу Монте-Карло с использованием марковских цепей*<br>
# Суть метода Монте-Карло состоит в описании процесса, представленного точной математической моделью, с помощью вероятностных характеристик. Марковские цепи являются полезным дополнением к методу Монте-Карло, в наибольшей степени востребованным в моделировании временных рядов. Сам по себе метод Монте-Карло позволяет узнать только распределение ряда данных, но не отследить его изменение во времени. Именно здесь в действие вступают марковские цепи. С их помощью вычисляются вероятности перехода между состояниями, — учитывая их, рассматриваем отдельные “шаги” процесса, а не просто вычисляем общий интеграл. В результате мы получаем возможность проводить моделирование временных рядов, а не просто вычисление интеграла. (Це́пь Ма́ркова — последовательность случайных событий с конечным или счётным числом исходов, где вероятность наступления каждого события зависит только от состояния, достигнутого в предыдущем событии. Характеризуется тем свойством, что, говоря нестрого, при фиксированном настоящем будущее независимо от прошлого.).<br>
#
# В физике метод МСМС используется, например, для изучения влияния квантовых переходов в отдельных молекулах на совокупные ансамблевые измерения, проводимые в системе в разные моменты времени. В нашем случае система описывается следующими правилами.<br>
#
# 1. В марковском процессе вероятность перехода к будущему состоянию зависит только от текущего состояния (не от прошлых состояний).<br>
#
# 2. Система имеет физическое ограничение, выражаемое через распределение Больцмана для энергии:
# $\frac{T_{ij}}{T_{ji}} = e^{-b(E_i - E_j)}$
# Его нужно воспринимать как отдельный
# принцип реализации, даже не пытаясь понять теоретическое обоснование
# (конечно, если вы не физик).<br>
#
# Моделирование по методу МСМС реализуется следующим образом.<br>
# 1. Случайным образом выбираем начальное состояние каждого отдельного узла (элемента) решетки.<br>
#
# 2. На каждого временном шаге выбираем отдельный узел решетки и изменяем его спин (направление магнитного поля).<br>
#
# 3. Согласно известным физическим законам рассчитываем, насколько изменилась энергия элемента при переключении спина. Существует всего несколько возможностей.<br>
#
# — Изменение энергии выражается отрицательным числом — осуществляется переход в более низкое энергетическое состояние, которое является наиболее предпочтительным вариантом. В этом случае состояние сохраняется и выполняется переход к следующему временному шагу.<br>
#
# — Изменение энергии представляется неотрицательным значением — вероятность такого перехода рассчитывается как е(изменение энергии), что в полной мере соответствует правилу 2.<br>
#
# Продолжайте выполнять шаги 2 и 3 до завершения процесса — получения наиболее вероятного состояния для проводимого совокупного измерения.<br>
#
# Рассмотрим детали реализации модели Изинга. Представим материал, состоящий из множества объектов, расположенных в узлах двумерной сетки, каждый из которых обладает магнитным моментом (спином), характеризующимся направлением поля вверх или вниз. В начальный момент времени направление поля у всех объектов выбирается случайным образом. Нам нужно описать эволюцию системы таких объектов из случайного состояния в наиболее упорядоченное состояние, происходящую при низкой температуре (модель Изинга чаще используется для описания равновесных состояний ферромагнитных материалов, а не для изучения временных аспектов их перехода в состояние равновесия. Тем не менее мы будем рассматривать временные ряды, описывающие эволюцию системы во времени).
# Инициализируем систему следующим образом.<br>

# %%
##НАСТРОЙКА
N = 5 # ширина сетки
M = 5 # высота сетки
## Установка температуры
temperature = 0.5
BETA = 1/temperature

# %% [markdown]
# Для случайной инициализации стартового блока обратимся к служебным методам.

# %%
def initRandState (N, М) :
    block = np.random.choice ([-1, 1], size = (N, M) )
    return block

# %% [markdown]
# Кроме того, нам нужно вычислить энергию выравнивания центрального блока относительно его соседей.

# %%
def costForCenterState(state, i, j, n, m) :
    centers = state[i, j]
    neighbors = [ ( (i + 1) % n, j), ((i - 1) % n, j), (i, (j + 1) % m), (i, (j - 1) % m) ]
## Обратите внимание на использование аргумента % n,
## указывающего на периодичность условия.
## Игнорируйте его, если в нем нет необходимости, -
## это всего лишь физическое ограничение для двумерных
## систем, которые можно описать через поверхность тора
    interactionE = [state[х, у] * centers for (х, у) in neighbors]
    return np.sum(interactionE)

# %% [markdown]
# Определим намагниченность всего блока в данном состоянии.

# %%
def magnetizationForState(state) :
    return np.sum(state)

# %% [markdown]
# Этапы моделирования процесса по методу МСМС, рассматриваемому ранее, реализуются следующим образом.

# %%
def mcmcAdjust(state, BETA=2) :
    n = state.shape[0]
    m = state.shape[1]
    x = np.random.randint(0, n)
    y = np.random.randint(0, m)
    centers = state[x, y]
    cost = costForCenterState(state, x, y, n, m)
    if cost < 0:
        centers *= -1
    elif np.random.random() < np.exp(-cost * BETA):
        centers *= -1
    state [x, y] = centers
    return state

# %% [markdown]
# Для запуска процесса моделирования нам потребуются функции регистрации данных и перенастройки модели МСМС.

# %%
def runState (state, n_steps, snapsteps = None):
    if snapsteps is None:
        snapsteps = np.linspace(0, n_steps, num = round(n_steps /(M * N * 100) ),dtype = np.int32)
    saved_states = []
    sp = 0
    magnet_hist = []
    for i in range(n_steps) :
        state = mcmcAdjust(state)
        magnet_hist.append(magnetizationForState(state))
        if sp < len (snapsteps) and i == snapsteps[sp]:
            saved_states.append(np.copy(state))
        sp += 1
    return state, saved_states, magnet_hist

# %% [markdown]
# Запуск моделирования

# %%
import matplotlib.pyplot as plt

# %%
def show_chessboard(matrix1, matrix2):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

    ax1.imshow(matrix1, cmap="gray", interpolation="nearest")
    ax1.set_title('init state')
    ax1.set_xticks([])
    ax1.set_yticks([])

    ax2.imshow(matrix2, cmap="gray", interpolation="nearest")
    ax2.set_title('final state')
    ax2.set_xticks([])
    ax2.set_yticks([])

    plt.show()

# %%
#МОДЕЛИРОВАНИЕ
init_state = np.array(initRandState(N, M))
final_state = np.array(runState(np.copy(init_state), 1000)[0])

# %%
show_chessboard(init_state, final_state)

# %% [markdown]
# Чтобы сделать определенные выводы по результатам моделирования, нужно сравнить начальное и конечное состояния системы.<br>
# На рисунке показано случайно сгенерированное распределение начальных состояний. Хотя можно ожидать более равномерного их распределения, не забывайте, что при вероятностном подходе получить распределение состояний в идеальном шахматном порядке почти невозможно. Попробуйте перегенерировать начальную сетку несколько раз, чтобы убедиться в том, что строгое “случайное” или абсолютное шахматное распределение крайне маловероятны. Тем не менее обратите внимание на то, что в начальный момент времени в каждом из двух возможных состояний находится примерно половина узлов. Примите к сведению, что любые шаблоны начальных состояний, которые только вам удастся распознать, будут всего лишь плодом воображения — человеческому мозгу свойственно находить известные ему картины везде, даже там, где их нет<br>.

# %% [markdown]
# Передадим начальное состояние в функцию runState(), выполним моделирование для 1000 временных шагов и изучим конечный результат, показанный на рисунке. Мы получили распределение состояний через 1000 временных шагов. Результат моделирования позволяет сделать как минимум два интересных вывода. Во-первых, доминирующие состояния изменились на противоположные через 1000 шагов. Во-вторых, в числовом выражении текущее доминирующее состояние не так сильно, как противоположное доминирующее состояние в начальный момент времени. Это указывает на то, что под воздействием температуры узлы могут выходить из доминирующего состояния, даже если предыдущее состояние оказывается более предпочтительным. Чтобы лучше понять динамику процесса, нужно анализировать обобщенные характеристики, такие как намагниченность, или отслеживать временные изменения в двумерных данных по специально созданным анимационным роликам.<br>
#
#
# Определим намагниченность материала в разные моменты времени для большого количества независимых сеансов моделирования (рисунок 3.4).

# %%
import matplotlib
## Каждый временной ряд представляет отдельный результат
results = []
for i in range (100) :
    init_state = initRandState (N, M)
    final_state, states, magnet_hist = runState(init_state, 1000)
    results.append(magnet_hist)

## Построение графиков каждого ряда для оценки их перекрываемости
for mh in results:
    matplotlib.pyplot.plot(mh, 'r', alpha=0.2)

# %% [markdown]
# *Рис. 3.4. Сто независимых сеансов моделирования процесса изменения намагниченности системы при низкой температуре со случайным распределением состояний начальной сетки*

# %% [markdown]
# Изучение кривых намагничивания — это только один из способов отслеживания эволюции системы во времени. В качестве альтернативного варианта можно проводить исследование двумерных временных рядов, каждый из которых представляет данные состояния всей системы в отдельный момент времени. Или же можно проследить на каждом этапе моделирования за изменением других важных сводных характеристик, например, энтропии или общей энергии. Заметьте, что в нашей модели намагниченность и энтропия являются связанными величинами, поскольку выступают функциями распределения состояний узлов решетки, но определяют совершенно разные физические характеристики.<br>
# Полученные результаты можно использовать в дальнейших исследованиях подобно тому, как это было сделано при моделировании поведения таксопарка (несмотря на сильные различия в моделях). Повышенный интерес вызывают следующее задачи.<br>
#
# • Настройки конвейера данных на основе сгенерированных в результате моделирования временных рядов<br>
#
# • Тестирование методов машинного обучения на синтезированных данных для изучения возможности их применения к собираемым данным до очистки и предварительной обработки<br>
#
# • Изучение важных характеристик физической модели для лучшего понимания базовой системы.<br>
#
# **Замечания по моделированию**
#
# Мы рассмотрели несколько примеров моделирования сильно различающихся систем, поведение которых изменяется во времени. Нашей основной задачей было построение моделей данных, описывающих поведение потребителей (внесение пожертвований членами благотворительной организации), городской инфраструктуры (службы такси) и замкнутой физической системы (упорядочение случайно направленного магнитного поля). После детального изучения этих примеров вы почувствуете себя комфортно, рассматривая программный код моделирования более сложных процессов, а также используя полученные результаты для решения практических задач.<br>
#
# Получив в свое распоряжение некий набор данных, вы, скорее всего, выдвигали предположения о его структуре и возможности практического использования, но не имели возможности их проверить. Моделирование данных позволяет получить ответы на очень многие вопросы. Результаты моделирования подтверждают или опровергают самые смелые предположения о данных, основанные на умозрительных рассуждениях и изучении количественных характеристик.<br>
#
# **Статистическое моделирование**
#
# Статистическое моделирование — это традиционный способ изучения временных рядов. Оно выполняется в задачах с известными динамическими характеристиками стохастической системы и позволяет оценить неизвестные параметры или понять, как сделанные предположения влияют на процесс оценки таких параметров (наглядный пример приведен в последующих главах). Для многих физических систем статистическое моделирование оказывается предпочтительнее других методов оценки.<br>
#
# Статистическое моделирование временных рядов также находит широкое применение, например, в задачах нахождения количественных показателей оценки точности модели. Точность традиционных статистических моделей, таких как ARIMA, рассчитывается согласно строго заданным аналитическим формулам.<br>
# Это означает, что при описании систем с помощью известных статистических методов численную оценку дисперсии и точности модели можно получить без проведения большого количества сеансов моделирования.<br>
#
# **Модели глубокого обучения**
#
# Моделирование временных рядов методами глубокого обучения — это новая, но весьма многообещающая дисциплина науки о данных. С помощью технологий глубокого обучения во временных рядах можно обнаружить сложные динамические процессы, зачастую скрытые для понимания даже опытных специалистов по анализу данных. Это же является недостатком технологии — чаще всего специалисты по анализу данных не имеют ни малейшего представления о принципах изучения обнаруженных динамических процессов.<br>
#
# Алгоритмы глубокого обучения предоставляют широкие возможности по защите исследуемых данных. Например, с помощью методов глубокого обучения можно синтезировать временные ряды неоднородных данных, впоследствии обрабатываемых медицинскими приложениями, на основе реальных временных рядов, уязвимых к утечке конфиденциальной информации. Такой защищенный набор данных, если он действительно будет получен, станет неоценимым источником медицинских сведений, лишенным недостатков исходных временных рядов.<br>
#
# **Дополнительные источники**
#
# Cristobal Esteban, Stephanie L. Hyland, and Gunnar Ratsch, “Real-Valued (Medical) Time Series Generation with Recurrent Conditional GANs,” unpublished manuscript, last revised December 4, 2017, https://perma.cc/Q69W-L44Z
#
# Авторы работы описывают принципы использования генеративно-состязательных сетей для синтезирования реалистично выглядящих разнородных медицинских временных рядов. Это пример использования методов глубокого обучения для получения этически выверенных, юридически обоснованных и (хочется верить) защищенных от утечек наборов медицинских данных, которые могут широко использоваться при разработке медицинских приложений, основанных на алгоритмах машинного и глубокого обучения.<br>
#
# Gordon Reikard and W, Erick Rogers, “Forecasting Ocean Waves: Comparing a Physicsbased Model with Statistical Models,” Coastal Engineering 58 (2011): 409-16, https://perma.cc/89DJ-ZENZ<br>
#
# В этой статье проводится сравнение двух совершенно разных моделей описания системы — статистической и физической. Авторы работы приходят к выводу, что в задачах прогнозирования выбор модели определяется временной шкалой анализируемых данных. Хотя статья посвящена преимущественно прогнозированию, рассматриваемые в ней вопросы имеют самое непосредственное отношение к моделированию, основанному на тех же принципах, что и прогнозирование.<br>
#
# Wolfgang Hardie, Joel Horowitz, and Jens-Peter Kreiss, “Bootstrap Methods for Time Series,” International Statistical Review / Revue Internationale de Statistique 71, no. 2 (2003): 435-59, https: //perma.cc/6CQA-EG2E
#
# Критический взгляд на недостатки статистических методов моделирования данных с временными зависимостями от 2005 года. В характерной для научных сотрудников манере авторы объясняют, почему бутстрап-методы анализа демонстрируют низкую эффективность в процессе анализа временных рядов по сравнению с данными других типов. В статье также рассматриваются наиболее перспективные (на момент ее написания) методы анализа временных данных. Технологии моделирования не сильно изменились с тех пор, и статья остается актуальной и сегодня.
